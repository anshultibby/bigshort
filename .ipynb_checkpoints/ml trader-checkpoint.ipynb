# %%
import numpy as np
import pandas as pd
import robin_stocks as r
import inspect
import math
import matplotlib.pyplot as plt
import datetime as dt

# %% [markdown]
# # Trade options using RL - https://towardsdatascience.com/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# ## State space definition
# Select 10 options around the atm price
# 1. cash - money held as cash - 1
# 2. price - bid prices of options we can trade - n
#     3. vegas - list of vega for each option - n
#     4. gammma - list of gammas for each option - n
#     5. deltas - list of deltas for each option - n
#     6. thetas - list of thetas for each option - n
#     7. ivs - list of ivs for each option - n
# 3.  how many days to earning - 1
# 4. for each options how many days from earnings is the option expiration date - n
# 8. spy - spy price - 1
# 9. stock - price of share - 1
# 10. position - for each option are we -1,0 or 1 - n
# 11. cost - for each option what was our purchase price - n
#
# ## Action space definition
# a - buy/sell/hold - for each option either -1,0,1 - n
#
# ## Reward function
# r(s,a,s') - cash + price * position
#
# ## Policy
# p(s) - probability distribution of actions to take at s
#
# ## Q-value
# Q(a,s) - expected value of taking action a at state s

# %%
my_trader = r
my_trader.login(username="anshul.tibrewal2203@gmail.com", password="Icangeta45!")
bs = "bs"

# %%
r.options.get_chains("AAPL")
# Out:
# {'id': '7dd906e5-7d4b-4161-a3fe-2c3b62038482',
#  'symbol': 'AAPL',
#  'can_open_position': True,
#  'cash_component': None,
#  'expiration_dates': ['2020-09-25',
#   '2020-10-02',
#   '2020-10-09',
#   '2020-10-16',
#   '2020-10-23',
#   '2020-10-30',
#   '2020-11-20',
#   '2020-12-18',
#   '2021-01-15',
#   '2021-03-19',
#   '2021-04-16',
#   '2021-06-18',
#   '2021-09-17',
#   '2022-01-21',
#   '2022-06-17',
#   '2022-09-16',
#   '2023-01-20'],
#  'trade_value_multiplier': '100.0000',
#  'underlying_instruments': [{'id': '3b1b2528-8887-4410-bce4-b5128eac4a86',
#    'instrument': 'https://api.robinhood.com/instruments/450dfc6d-5510-4d40-abfb-f633b7d9be3e/',
#    'quantity': 100}],
#  'min_ticks': {'above_tick': '0.05',
#   'below_tick': '0.01',
#   'cutoff_price': '3.00'}}

# %% [markdown]
# ## Get all stock data we need for state space

# %%
def get_stock_state(ticker="AAPL"):
    stock_prices = r.get_stock_historicals(ticker, interval='day', span='3month', bounds='regular')
    earnings = r.stocks.get_earnings(ticker)
    return {"P" : stock_prices, "e" : earnings}

# %%
get_stock_state()
# Out:
# {'P': [{'begins_at': '2020-06-19T00:00:00Z',
#    'open_price': '88.658800',
#    'close_price': '87.430000',
#    'high_price': '89.140000',
#    'low_price': '86.287500',
#    'volume': 264475808,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-06-22T00:00:00Z',
#    'open_price': '87.835000',
#    'close_price': '89.717500',
#    'high_price': '89.865000',
#    'low_price': '87.787500',
#    'volume': 135445264,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-06-23T00:00:00Z',
#    'open_price': '91.000000',
#    'close_price': '91.632500',
#    'high_price': '93.095000',
#    'low_price': '90.567500',
#    'volume': 212155476,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-06-24T00:00:00Z',
#    'open_price': '91.250000',
#    'close_price': '90.015000',
#    'high_price': '92.197500',
#    'low_price': '89.630000',
#    'volume': 192623396,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-06-25T00:00:00Z',
#    'open_price': '90.175000',
#    'close_price': '91.210000',
#    'high_price': '91.250000',
#    'low_price': '89.392500',
#    'volume': 137522512,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-06-26T00:00:00Z',
#    'open_price': '91.102500',
#    'close_price': '88.407500',
#    'high_price': '91.330000',
#    'low_price': '88.255000',
#    'volume': 205256844,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-06-29T00:00:00Z',
#    'open_price': '88.312500',
#    'close_price': '90.445000',
#    'high_price': '90.543400',
#    'low_price': '87.820000',
#    'volume': 130646076,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-06-30T00:00:00Z',
#    'open_price': '90.020000',
#    'close_price': '91.200000',
#    'high_price': '91.495000',
#    'low_price': '90.000000',
#    'volume': 140223284,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-01T00:00:00Z',
#    'open_price': '91.280000',
#    'close_price': '91.027500',
#    'high_price': '91.840000',
#    'low_price': '90.977500',
#    'volume': 110737236,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-02T00:00:00Z',
#    'open_price': '91.962500',
#    'close_price': '91.027500',
#    'high_price': '92.617500',
#    'low_price': '90.910000',
#    'volume': 114041468,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-06T00:00:00Z',
#    'open_price': '92.500000',
#    'close_price': '93.462500',
#    'high_price': '93.945000',
#    'low_price': '92.467500',
#    'volume': 118655652,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-07T00:00:00Z',
#    'open_price': '93.852500',
#    'close_price': '93.172500',
#    'high_price': '94.655000',
#    'low_price': '93.057500',
#    'volume': 112424456,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-08T00:00:00Z',
#    'open_price': '94.180000',
#    'close_price': '95.342500',
#    'high_price': '95.375000',
#    'low_price': '94.090000',
#    'volume': 117091880,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-09T00:00:00Z',
#    'open_price': '96.262500',
#    'close_price': '95.682500',
#    'high_price': '98.477500',
#    'low_price': '94.672500',
#    'volume': 125642608,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-10T00:00:00Z',
#    'open_price': '95.335000',
#    'close_price': '95.920000',
#    'high_price': '95.980000',
#    'low_price': '94.705200',
#    'volume': 90257320,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-13T00:00:00Z',
#    'open_price': '97.265000',
#    'close_price': '95.477500',
#    'high_price': '99.955000',
#    'low_price': '95.257500',
#    'volume': 191649140,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-14T00:00:00Z',
#    'open_price': '94.840000',
#    'close_price': '97.057500',
#    'high_price': '97.255000',
#    'low_price': '93.877500',
#    'volume': 170989364,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-15T00:00:00Z',
#    'open_price': '98.990000',
#    'close_price': '97.725000',
#    'high_price': '99.247500',
#    'low_price': '96.490000',
#    'volume': 153197932,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-16T00:00:00Z',
#    'open_price': '96.562500',
#    'close_price': '96.522500',
#    'high_price': '97.405000',
#    'low_price': '95.905000',
#    'volume': 110577672,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-17T00:00:00Z',
#    'open_price': '96.987500',
#    'close_price': '96.327500',
#    'high_price': '97.147500',
#    'low_price': '95.840000',
#    'volume': 92186900,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-20T00:00:00Z',
#    'open_price': '96.416200',
#    'close_price': '98.357500',
#    'high_price': '98.500000',
#    'low_price': '96.062500',
#    'volume': 90317908,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-21T00:00:00Z',
#    'open_price': '99.172500',
#    'close_price': '97.000000',
#    'high_price': '99.250000',
#    'low_price': '96.742500',
#    'volume': 103645836,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-22T00:00:00Z',
#    'open_price': '96.692500',
#    'close_price': '97.272500',
#    'high_price': '97.975000',
#    'low_price': '96.602500',
#    'volume': 89001652,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-23T00:00:00Z',
#    'open_price': '96.998400',
#    'close_price': '92.845000',
#    'high_price': '97.077500',
#    'low_price': '92.009800',
#    'volume': 197004432,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-24T00:00:00Z',
#    'open_price': '90.987500',
#    'close_price': '92.615000',
#    'high_price': '92.970000',
#    'low_price': '89.145000',
#    'volume': 185438864,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-27T00:00:00Z',
#    'open_price': '93.710000',
#    'close_price': '94.810000',
#    'high_price': '94.905000',
#    'low_price': '93.480000',
#    'volume': 121214192,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-28T00:00:00Z',
#    'open_price': '94.367500',
#    'close_price': '93.252500',
#    'high_price': '94.549600',
#    'low_price': '93.247500',
#    'volume': 103625500,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-29T00:00:00Z',
#    'open_price': '93.750000',
#    'close_price': '95.040000',
#    'high_price': '95.230000',
#    'low_price': '93.712500',
#    'volume': 90329256,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-30T00:00:00Z',
#    'open_price': '94.187500',
#    'close_price': '96.190000',
#    'high_price': '96.297500',
#    'low_price': '93.767500',
#    'volume': 158130020,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-07-31T00:00:00Z',
#    'open_price': '102.883800',
#    'close_price': '106.260000',
#    'high_price': '106.415000',
#    'low_price': '100.825000',
#    'volume': 374295468,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-03T00:00:00Z',
#    'open_price': '108.200000',
#    'close_price': '108.937500',
#    'high_price': '111.636400',
#    'low_price': '107.892500',
#    'volume': 308151388,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-04T00:00:00Z',
#    'open_price': '109.132500',
#    'close_price': '109.665000',
#    'high_price': '110.790000',
#    'low_price': '108.387500',
#    'volume': 172792368,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-05T00:00:00Z',
#    'open_price': '109.377500',
#    'close_price': '110.062500',
#    'high_price': '110.392500',
#    'low_price': '108.897500',
#    'volume': 121991952,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-06T00:00:00Z',
#    'open_price': '110.405000',
#    'close_price': '113.902500',
#    'high_price': '114.412500',
#    'low_price': '109.797500',
#    'volume': 202428900,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-07T00:00:00Z',
#    'open_price': '113.205000',
#    'close_price': '111.112500',
#    'high_price': '113.675000',
#    'low_price': '110.292500',
#    'volume': 198045612,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-10T00:00:00Z',
#    'open_price': '112.600000',
#    'close_price': '112.727500',
#    'high_price': '113.775000',
#    'low_price': '110.000000',
#    'volume': 212403424,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-11T00:00:00Z',
#    'open_price': '111.968800',
#    'close_price': '109.375000',
#    'high_price': '112.482500',
#    'low_price': '109.106700',
#    'volume': 187902376,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-12T00:00:00Z',
#    'open_price': '110.497500',
#    'close_price': '113.010000',
#    'high_price': '113.275000',
#    'low_price': '110.297500',
#    'volume': 165944820,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-13T00:00:00Z',
#    'open_price': '114.430000',
#    'close_price': '115.010000',
#    'high_price': '116.042500',
#    'low_price': '113.927500',
#    'volume': 210082064,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-14T00:00:00Z',
#    'open_price': '114.828800',
#    'close_price': '114.907500',
#    'high_price': '115.000000',
#    'low_price': '113.045000',
#    'volume': 165565208,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-17T00:00:00Z',
#    'open_price': '116.062500',
#    'close_price': '114.607500',
#    'high_price': '116.087500',
#    'low_price': '113.962500',
#    'volume': 119561444,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-18T00:00:00Z',
#    'open_price': '114.352500',
#    'close_price': '115.562500',
#    'high_price': '116.000000',
#    'low_price': '114.007500',
#    'volume': 105633540,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-19T00:00:00Z',
#    'open_price': '115.983200',
#    'close_price': '115.707500',
#    'high_price': '117.162500',
#    'low_price': '115.610000',
#    'volume': 145538008,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-20T00:00:00Z',
#    'open_price': '115.750000',
#    'close_price': '118.275000',
#    'high_price': '118.392000',
#    'low_price': '115.733400',
#    'volume': 126907188,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-21T00:00:00Z',
#    'open_price': '119.262500',
#    'close_price': '124.370000',
#    'high_price': '124.868000',
#    'low_price': '119.250000',
#    'volume': 338054640,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-24T00:00:00Z',
#    'open_price': '128.697500',
#    'close_price': '125.857500',
#    'high_price': '128.785000',
#    'low_price': '123.936200',
#    'volume': 345937768,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-25T00:00:00Z',
#    'open_price': '124.697500',
#    'close_price': '124.825000',
#    'high_price': '125.179300',
#    'low_price': '123.052500',
#    'volume': 211495788,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-26T00:00:00Z',
#    'open_price': '126.179100',
#    'close_price': '126.522500',
#    'high_price': '126.992500',
#    'low_price': '125.082500',
#    'volume': 163022268,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-27T00:00:00Z',
#    'open_price': '127.142500',
#    'close_price': '125.010000',
#    'high_price': '127.485000',
#    'low_price': '123.832500',
#    'volume': 155552384,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-28T00:00:00Z',
#    'open_price': '126.012500',
#    'close_price': '124.807500',
#    'high_price': '126.442500',
#    'low_price': '124.577500',
#    'volume': 187629916,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-08-31T00:00:00Z',
#    'open_price': '127.580000',
#    'close_price': '129.040000',
#    'high_price': '131.000000',
#    'low_price': '126.000000',
#    'volume': 225702688,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-09-01T00:00:00Z',
#    'open_price': '132.760000',
#    'close_price': '134.180000',
#    'high_price': '134.800000',
#    'low_price': '130.530000',
#    'volume': 152470142,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-09-02T00:00:00Z',
#    'open_price': '137.590000',
#    'close_price': '131.400000',
#    'high_price': '137.980000',
#    'low_price': '127.000000',
#    'volume': 200118991,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-09-03T00:00:00Z',
#    'open_price': '126.910000',
#    'close_price': '120.880000',
#    'high_price': '128.840000',
#    'low_price': '120.500000',
#    'volume': 257599640,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-09-04T00:00:00Z',
#    'open_price': '120.070000',
#    'close_price': '120.960000',
#    'high_price': '123.700000',
#    'low_price': '110.890000',
#    'volume': 332607163,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-09-08T00:00:00Z',
#    'open_price': '113.950000',
#    'close_price': '112.820000',
#    'high_price': '118.990000',
#    'low_price': '112.680000',
#    'volume': 231366563,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-09-09T00:00:00Z',
#    'open_price': '117.260000',
#    'close_price': '117.320000',
#    'high_price': '119.140000',
#    'low_price': '115.260000',
#    'volume': 176940455,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-09-10T00:00:00Z',
#    'open_price': '120.360000',
#    'close_price': '113.490000',
#    'high_price': '120.500000',
#    'low_price': '112.500000',
#    'volume': 182274391,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-09-11T00:00:00Z',
#    'open_price': '114.570000',
#    'close_price': '112.000000',
#    'high_price': '115.230000',
#    'low_price': '110.000000',
#    'volume': 180860325,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-09-14T00:00:00Z',
#    'open_price': '114.720000',
#    'close_price': '115.355000',
#    'high_price': '115.930000',
#    'low_price': '112.800000',
#    'volume': 140150087,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-09-15T00:00:00Z',
#    'open_price': '118.330000',
#    'close_price': '115.540000',
#    'high_price': '118.829000',
#    'low_price': '113.610000',
#    'volume': 184642039,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-09-16T00:00:00Z',
#    'open_price': '115.230000',
#    'close_price': '112.130000',
#    'high_price': '116.000000',
#    'low_price': '112.040000',
#    'volume': 155026675,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-09-17T00:00:00Z',
#    'open_price': '109.720000',
#    'close_price': '110.340000',
#    'high_price': '112.200000',
#    'low_price': '108.710000',
#    'volume': 178010968,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'},
#   {'begins_at': '2020-09-18T00:00:00Z',
#    'open_price': '110.400000',
#    'close_price': '106.840000',
#    'high_price': '110.880000',
#    'low_price': '106.090000',
#    'volume': 287104882,
#    'session': 'reg',
#    'interpolated': False,
#    'symbol': 'AAPL'}],
#  'e': [{'symbol': 'AAPL',
#    'instrument': 'https://api.robinhood.com/instruments/450dfc6d-5510-4d40-abfb-f633b7d9be3e/',
#    'year': 2019,
#    'quarter': 1,
#    'eps': {'estimate': '4.170000', 'actual': '4.180000'},
#    'report': {'date': '2019-01-29', 'timing': 'pm', 'verified': True},
#    'call': {'datetime': '2019-04-30T21:00:00Z',
#     'broadcast_url': None,
#     'replay_url': 'http://mmm.wallstreethorizon.com/u.asp?u=174639'}},
#   {'symbol': 'AAPL',
#    'instrument': 'https://api.robinhood.com/instruments/450dfc6d-5510-4d40-abfb-f633b7d9be3e/',
#    'year': 2019,
#    'quarter': 2,
#    'eps': {'estimate': '2.360000', 'actual': '2.460000'},
#    'report': {'date': '2019-04-30', 'timing': 'pm', 'verified': True},
#    'call': {'datetime': '2019-07-30T21:00:00Z',
#     'broadcast_url': None,
#     'replay_url': 'http://mmm.wallstreethorizon.com/u.asp?u=174639'}},
#   {'symbol': 'AAPL',
#    'instrument': 'https://api.robinhood.com/instruments/450dfc6d-5510-4d40-abfb-f633b7d9be3e/',
#    'year': 2019,
#    'quarter': 3,
#    'eps': {'estimate': '2.100000', 'actual': '2.180000'},
#    'report': {'date': '2019-07-30', 'timing': 'pm', 'verified': True},
#    'call': {'datetime': '2019-10-30T21:00:00Z',
#     'broadcast_url': None,
#     'replay_url': 'http://mmm.wallstreethorizon.com/u.asp?u=174639'}},
#   {'symbol': 'AAPL',
#    'instrument': 'https://api.robinhood.com/instruments/450dfc6d-5510-4d40-abfb-f633b7d9be3e/',
#    'year': 2019,
#    'quarter': 4,
#    'eps': {'estimate': '2.830000', 'actual': '3.030000'},
#    'report': {'date': '2019-10-30', 'timing': 'pm', 'verified': True},
#    'call': {'datetime': '2020-01-28T22:00:00Z',
#     'broadcast_url': None,
#     'replay_url': 'http://mmm.wallstreethorizon.com/u.asp?u=174639'}},
#   {'symbol': 'AAPL',
#    'instrument': 'https://api.robinhood.com/instruments/450dfc6d-5510-4d40-abfb-f633b7d9be3e/',
#    'year': 2020,
#    'quarter': 1,
#    'eps': {'estimate': '4.540000', 'actual': '4.990000'},
#    'report': {'date': '2020-01-28', 'timing': 'pm', 'verified': True},
#    'call': None},
#   {'symbol': 'AAPL',
#    'instrument': 'https://api.robinhood.com/instruments/450dfc6d-5510-4d40-abfb-f633b7d9be3e/',
#    'year': 2020,
#    'quarter': 2,
#    'eps': {'estimate': '2.260000', 'actual': '2.550000'},
#    'report': {'date': '2020-04-30', 'timing': 'pm', 'verified': True},
#    'call': {'datetime': '2020-04-30T21:00:00Z',
#     'broadcast_url': None,
#     'replay_url': 'http://mmm.wallstreethorizon.com/u.asp?u=174639'}},
#   {'symbol': 'AAPL',
#    'instrument': 'https://api.robinhood.com/instruments/450dfc6d-5510-4d40-abfb-f633b7d9be3e/',
#    'year': 2020,
#    'quarter': 3,
#    'eps': {'estimate': '2.040000', 'actual': '2.580000'},
#    'report': {'date': '2020-07-30', 'timing': 'pm', 'verified': True},
#    'call': {'datetime': '2020-07-30T21:00:00Z',
#     'broadcast_url': None,
#     'replay_url': 'http://mmm.wallstreethorizon.com/u.asp?u=174639'}},
#   {'symbol': 'AAPL',
#    'instrument': 'https://api.robinhood.com/instruments/450dfc6d-5510-4d40-abfb-f633b7d9be3e/',
#    'year': 2020,
#    'quarter': 4,
#    'eps': {'estimate': None, 'actual': None},
#    'report': {'date': '2020-10-28', 'timing': 'pm', 'verified': False},
#    'call': None}]}

# %%
# !!! fill out the specific option information
symbol = 'AAPL'
expirationDate = '2020-09-25'
strike = 200
optionType = 'call'
span = 'day' #available options are day,week,year, and 5year
#!!!
days = 20
chain = r.options.get_chains(symbol)
tradeable = r.options.find_tradable_options(symbol = symbol, expirationDate = chain["expiration_dates"][0])
historicalData = r.get_option_historicals(symbol,expirationDate,strike,optionType,span)

dates = []
closingPrices = []
openPrices = []

for item in historicalData:
#     print(item)
    dates.append(dt.datetime.strptime(item['begins_at'],'%Y-%m-%dT%H:%M:%SZ'))
    closingPrices.append(float(item['close_price']))
    openPrices.append(float(item['open_price']))

# print(openPrices)
#!!! I made it so it only got the last 30 days but you could delete these lines to get full year.
dates = dates[-days:]
closingPrices = closingPrices[-days:]
openPrices = openPrices[-days:]
#
start_date = dates[0]


# change the dates into a format that matplotlib can recognize.
# x = [dt.datetime.strptime(d,'%Y-%m-%dT%H:%M:%SZ') for d in dates]
x = []
for d in dates:
    seconds = (d - start_date).total_seconds()/86400
    x.append(seconds)
    


plt.figure(figsize=(5,4))
# plots the data.
plt.plot(x, closingPrices, 'ro')
# plt.plot(x, openPrices, 'bo')
plt.title("Option price for "+r.get_name_by_symbol(symbol)+" over time")
plt.xlabel("Dates")
plt.ylabel("Price")
plt.show()
# Out:
# Found Additional pages.
# Loading page 2 ...
# Loading page 3 ...
# Loading page 4 ...
# Loading page 5 ...
# Loading page 6 ...
# Loading page 7 ...
# Loading page 8 ...
# Loading page 9 ...
# Loading page 10 ...
# Loading page 11 ...
# Loading page 12 ...
# Loading page 13 ...
# Loading page 14 ...
# Loading page 15 ...
# Loading page 16 ...
# Loading page 17 ...
# Loading page 18 ...
# Loading page 19 ...
# Loading page 20 ...
# Loading page 21 ...
# Loading page 22 ...
# Loading page 23 ...
# Loading page 24 ...
# Loading page 25 ...
# Loading page 26 ...
# Loading page 27 ...
# Getting the option ID failed. Perhaps the expiration date is wrong format, or the strike price is wrong.
# 404 Client Error: Not Found for url: https://api.robinhood.com/marketdata/options/historicals/None/?span=week&interval=day&bounds=regular
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-ebea6a6fac2b> in <module>
#      15 openPrices = []
#      16
# ---> 17 for item in historicalData:
#      18 #     print(item)
#      19     dates.append(dt.datetime.strptime(item['begins_at'],'%Y-%m-%dT%H:%M:%SZ'))
#
# TypeError: 'NoneType' object is not iterable

# %%
print(historicalData[0])
# Out:
# {'begins_at': '2020-09-14T13:30:00Z', 'open_price': '20.430000', 'close_price': '20.430000', 'high_price': '20.430000', 'low_price': '20.430000', 'volume': 0, 'session': 'reg', 'interpolated': False, 'symbol': 'ENPH'}

# %% [markdown]
# ## Implementing Soft Actor Critic in this notebook

# %%
import math
import random

import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Normal

from IPython.display import clear_output
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import display

# %matplotlib inline

use_cuda = torch.cuda.is_available()
device   = torch.device("cuda" if use_cuda else "cpu")

# %% [markdown]
# ## Auxillary functions

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.capacity = capacity
        self.buffer = []
        self.position = 0
    
    def push(self, state, action, reward, next_state, done):
        if len(self.buffer) < self.capacity:
            self.buffer.append(None)
        self.buffer[self.position] = (state, action, reward, next_state, done)
        self.position = (self.position + 1) % self.capacity
    
    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        state, action, reward, next_state, done = map(np.stack, zip(*batch))
        return state, action, reward, next_state, done
    
    def __len__(self):
        return len(self.buffer)

# %%
class NormalizedActions():
    def _action(self, action):
        low  = -1
        high = 1
        
        action = low + (action + 1.0) * 0.5 * (high - low)
        action = np.clip(action, low, high)
        
        return action

    def _reverse_action(self, action):
        low  = -1
        high = 1
        
        action = 2 * (action - low) / (high - low) - 1
        action = np.clip(action, low, high)
        return action

# %% [markdown]
# ## Define Networks

# %%
class ValueNetwork(nn.Module):
    def __init__(self, state_dim, hidden_dim, init_w=3e-3):
        super(ValueNetwork, self).__init__()
        
        self.linear1 = nn.Linear(state_dim, hidden_dim)
        self.linear2 = nn.Linear(hidden_dim, hidden_dim)
        self.linear3 = nn.Linear(hidden_dim, 1)
        
        self.linear3.weight.data.uniform_(-init_w, init_w)
        self.linear3.bias.data.uniform_(-init_w, init_w)
        
    def forward(self, state):
        x = F.relu(self.linear1(state))
        x = F.relu(self.linear2(x))
        x = self.linear3(x)
        return x
        
        
class SoftQNetwork(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_size, init_w=3e-3):
        super(SoftQNetwork, self).__init__()
        
        self.linear1 = nn.Linear(num_inputs + num_actions, hidden_size)
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        self.linear3 = nn.Linear(hidden_size, 1)
        
        self.linear3.weight.data.uniform_(-init_w, init_w)
        self.linear3.bias.data.uniform_(-init_w, init_w)
        
    def forward(self, state, action):
        x = torch.cat([state, action], 1)
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        x = self.linear3(x)
        return x
        
        
class PolicyNetwork(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_size, init_w=3e-3, log_std_min=-20, log_std_max=2):
        super(PolicyNetwork, self).__init__()
        
        self.log_std_min = log_std_min
        self.log_std_max = log_std_max
        
        self.linear1 = nn.Linear(num_inputs, hidden_size)
        self.linear2 = nn.Linear(hidden_size, hidden_size)
        
        self.mean_linear = nn.Linear(hidden_size, num_actions)
        self.mean_linear.weight.data.uniform_(-init_w, init_w)
        self.mean_linear.bias.data.uniform_(-init_w, init_w)
        
        self.log_std_linear = nn.Linear(hidden_size, num_actions)
        self.log_std_linear.weight.data.uniform_(-init_w, init_w)
        self.log_std_linear.bias.data.uniform_(-init_w, init_w)
        
    def forward(self, state):
        x = F.relu(self.linear1(state))
        x = F.relu(self.linear2(x))
        
        mean    = self.mean_linear(x)
        log_std = self.log_std_linear(x)
        log_std = torch.clamp(log_std, self.log_std_min, self.log_std_max)
        
        return mean, log_std
    
    def evaluate(self, state, epsilon=1e-6):
        mean, log_std = self.forward(state)
        std = log_std.exp()
        
        normal = Normal(0, 1)
        z      = normal.sample()
        action = torch.tanh(mean+ std*z.to(device))
        log_prob = Normal(mean, std).log_prob(mean+ std*z.to(device)) - torch.log(1 - action.pow(2) + epsilon)
        return action, log_prob, z, mean, log_std
        
    
    def get_action(self, state):
        state = torch.FloatTensor(state).unsqueeze(0).to(device)
        mean, log_std = self.forward(state)
        std = log_std.exp()
        
        normal = Normal(0, 1)
        z      = normal.sample().to(device)
        action = torch.tanh(mean + std*z)
        
        action  = action.cpu()#.detach().cpu().numpy()
        return action[0]

# %% [markdown]
# ## Update functions

# %%
def update(batch_size,gamma=0.99,soft_tau=1e-2,):
    
    state, action, reward, next_state, done = replay_buffer.sample(batch_size)

    state      = torch.FloatTensor(state).to(device)
    next_state = torch.FloatTensor(next_state).to(device)
    action     = torch.FloatTensor(action).to(device)
    reward     = torch.FloatTensor(reward).unsqueeze(1).to(device)
    done       = torch.FloatTensor(np.float32(done)).unsqueeze(1).to(device)

    predicted_q_value1 = soft_q_net1(state, action)
    predicted_q_value2 = soft_q_net2(state, action)
    predicted_value    = value_net(state)
    new_action, log_prob, epsilon, mean, log_std = policy_net.evaluate(state)

    
    
# Training Q Function
    target_value = target_value_net(next_state)
    target_q_value = reward + (1 - done) * gamma * target_value
    q_value_loss1 = soft_q_criterion1(predicted_q_value1, target_q_value.detach())
    q_value_loss2 = soft_q_criterion2(predicted_q_value2, target_q_value.detach())


    soft_q_optimizer1.zero_grad()
    q_value_loss1.backward()
    soft_q_optimizer1.step()
    soft_q_optimizer2.zero_grad()
    q_value_loss2.backward()
    soft_q_optimizer2.step()    
# Training Value Function
    predicted_new_q_value = torch.min(soft_q_net1(state, new_action),soft_q_net2(state, new_action))
    target_value_func = predicted_new_q_value - log_prob
    value_loss = value_criterion(predicted_value, target_value_func.detach())

    
    value_optimizer.zero_grad()
    value_loss.backward()
    value_optimizer.step()
# Training Policy Function
    policy_loss = (log_prob - predicted_new_q_value).mean()

    policy_optimizer.zero_grad()
    policy_loss.backward()
    policy_optimizer.step()
    
    
    for target_param, param in zip(target_value_net.parameters(), value_net.parameters()):
        target_param.data.copy_(
            target_param.data * (1.0 - soft_tau) + param.data * soft_tau
        )

# %% [markdown]
# ## Initializations

# %%
env = NormalizedActions()

action_dim = env.action_space.shape[0]
state_dim  = env.observation_space.shape[0]
hidden_dim = 256

value_net        = ValueNetwork(state_dim, hidden_dim).to(device)
target_value_net = ValueNetwork(state_dim, hidden_dim).to(device)

soft_q_net1 = SoftQNetwork(state_dim, action_dim, hidden_dim).to(device)
soft_q_net2 = SoftQNetwork(state_dim, action_dim, hidden_dim).to(device)
policy_net = PolicyNetwork(state_dim, action_dim, hidden_dim).to(device)

for target_param, param in zip(target_value_net.parameters(), value_net.parameters()):
    target_param.data.copy_(param.data)
    

value_criterion  = nn.MSELoss()
soft_q_criterion1 = nn.MSELoss()
soft_q_criterion2 = nn.MSELoss()

value_lr  = 3e-4
soft_q_lr = 3e-4
policy_lr = 3e-4

value_optimizer  = optim.Adam(value_net.parameters(), lr=value_lr)
soft_q_optimizer1 = optim.Adam(soft_q_net1.parameters(), lr=soft_q_lr)
soft_q_optimizer2 = optim.Adam(soft_q_net2.parameters(), lr=soft_q_lr)
policy_optimizer = optim.Adam(policy_net.parameters(), lr=policy_lr)


replay_buffer_size = 1000000
replay_buffer = ReplayBuffer(replay_buffer_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-22651aa71a12> in <module>
# ----> 1 env = NormalizedActions(gym.make("Pendulum-v0"))
#       2
#       3 action_dim = env.action_space.shape[0]
#       4 state_dim  = env.observation_space.shape[0]
#       5 hidden_dim = 256
#
# NameError: name 'gym' is not defined

# %% [markdown]
# ## Training loop

# %%
while frame_idx < max_frames:
    state = env.reset()
    episode_reward = 0
    
    for step in range(max_steps):
        if frame_idx >1000:
            action = policy_net.get_action(state).detach()
            next_state, reward, done, _ = env.step(action.numpy())
        else:
            action = env.action_space.sample()
            next_state, reward, done, _ = env.step(action)
        
        
        replay_buffer.push(state, action, reward, next_state, done)
        
        state = next_state
        episode_reward += reward
        frame_idx += 1
        
        if len(replay_buffer) > batch_size:
            update(batch_size)
        
        if frame_idx % 1000 == 0:
            plot(frame_idx, rewards)
        
        if done:
            break
        
    rewards.append(episode_reward)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-942b399e34f6> in <module>
# ----> 1 while frame_idx < max_frames:
#       2     state = env.reset()
#       3     episode_reward = 0
#       4
#       5     for step in range(max_steps):
#
# NameError: name 'frame_idx' is not defined
