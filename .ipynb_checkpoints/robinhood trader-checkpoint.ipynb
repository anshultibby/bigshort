# %%
import robin_stocks as r
import inspect
import math
import matplotlib.pyplot as plt
import datetime as dt
import yfinance as yf
aapl = yf.Ticker("AAPL")

# %%
# !pip install yfinance

# %%
# Out:
# ('2020-09-24',
#  '2020-10-01',
#  '2020-10-08',
#  '2020-10-15',
#  '2020-10-22',
#  '2020-10-29',
#  '2020-11-19',
#  '2020-12-17',
#  '2021-01-14',
#  '2021-03-18',
#  '2021-04-15',
#  '2021-06-17',
#  '2021-09-16',
#  '2022-01-20',
#  '2022-06-16',
#  '2022-09-15')

# %%
my_trader = r
my_trader.login(username="anshul.tibrewal2203@gmail.com", password="Icangeta45!")
bs = "bs"
# Out:
# Enter Robinhood code for validation: 230020

# %%
r.options.get_chains("ENPH")
# Out:
# {'id': '53ac412e-d84f-4cd8-a239-fbbe93354dbd',
#  'symbol': 'ENPH',
#  'can_open_position': True,
#  'cash_component': None,
#  'expiration_dates': ['2020-10-16',
#   '2020-11-20',
#   '2021-01-15',
#   '2021-02-19',
#   '2021-05-21',
#   '2022-01-21',
#   '2023-01-20'],
#  'trade_value_multiplier': '100.0000',
#  'underlying_instruments': [{'id': 'b3bb1a74-ee77-4442-8f71-566fa5a2c705',
#    'instrument': 'https://api.robinhood.com/instruments/69cbc174-ead1-49a9-9c72-a8f015de474f/',
#    'quantity': 100}],
#  'min_ticks': {'above_tick': '0.05',
#   'below_tick': '0.01',
#   'cutoff_price': '3.00'}}

# %%
historicalData
# Out:
# [{'begins_at': '2020-09-14T13:30:00Z',
#   'open_price': '14.930000',
#   'close_price': '14.930000',
#   'high_price': '14.930000',
#   'low_price': '14.930000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T13:40:00Z',
#   'open_price': '14.930000',
#   'close_price': '15.900000',
#   'high_price': '15.930000',
#   'low_price': '14.930000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T13:50:00Z',
#   'open_price': '15.930000',
#   'close_price': '16.000000',
#   'high_price': '16.500000',
#   'low_price': '15.900000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T14:00:00Z',
#   'open_price': '16.000000',
#   'close_price': '15.430000',
#   'high_price': '16.000000',
#   'low_price': '15.430000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T14:10:00Z',
#   'open_price': '15.430000',
#   'close_price': '14.950000',
#   'high_price': '15.450000',
#   'low_price': '14.950000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T14:20:00Z',
#   'open_price': '14.950000',
#   'close_price': '15.080000',
#   'high_price': '15.080000',
#   'low_price': '14.900000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T14:30:00Z',
#   'open_price': '15.080000',
#   'close_price': '14.580000',
#   'high_price': '15.130000',
#   'low_price': '14.580000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T14:40:00Z',
#   'open_price': '14.580000',
#   'close_price': '14.730000',
#   'high_price': '14.750000',
#   'low_price': '14.580000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T14:50:00Z',
#   'open_price': '14.730000',
#   'close_price': '15.000000',
#   'high_price': '15.350000',
#   'low_price': '14.680000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T15:00:00Z',
#   'open_price': '15.000000',
#   'close_price': '15.280000',
#   'high_price': '15.430000',
#   'low_price': '15.000000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T15:10:00Z',
#   'open_price': '15.280000',
#   'close_price': '15.050000',
#   'high_price': '15.280000',
#   'low_price': '14.680000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T15:20:00Z',
#   'open_price': '15.050000',
#   'close_price': '15.200000',
#   'high_price': '15.730000',
#   'low_price': '14.900000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T15:30:00Z',
#   'open_price': '15.200000',
#   'close_price': '15.080000',
#   'high_price': '15.230000',
#   'low_price': '15.080000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T15:40:00Z',
#   'open_price': '15.100000',
#   'close_price': '14.930000',
#   'high_price': '15.100000',
#   'low_price': '14.930000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T15:50:00Z',
#   'open_price': '14.930000',
#   'close_price': '14.730000',
#   'high_price': '14.950000',
#   'low_price': '14.450000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T16:00:00Z',
#   'open_price': '14.730000',
#   'close_price': '15.000000',
#   'high_price': '15.000000',
#   'low_price': '14.730000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T16:10:00Z',
#   'open_price': '15.000000',
#   'close_price': '14.950000',
#   'high_price': '15.050000',
#   'low_price': '14.950000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T16:20:00Z',
#   'open_price': '14.950000',
#   'close_price': '14.850000',
#   'high_price': '14.950000',
#   'low_price': '14.830000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T16:30:00Z',
#   'open_price': '14.830000',
#   'close_price': '14.780000',
#   'high_price': '14.850000',
#   'low_price': '14.650000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T16:40:00Z',
#   'open_price': '14.750000',
#   'close_price': '15.130000',
#   'high_price': '15.430000',
#   'low_price': '14.750000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T16:50:00Z',
#   'open_price': '15.130000',
#   'close_price': '15.150000',
#   'high_price': '15.200000',
#   'low_price': '15.100000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T17:00:00Z',
#   'open_price': '15.150000',
#   'close_price': '15.230000',
#   'high_price': '15.330000',
#   'low_price': '15.150000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T17:10:00Z',
#   'open_price': '15.230000',
#   'close_price': '15.000000',
#   'high_price': '15.300000',
#   'low_price': '15.000000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T17:20:00Z',
#   'open_price': '15.000000',
#   'close_price': '15.050000',
#   'high_price': '15.080000',
#   'low_price': '15.000000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T17:30:00Z',
#   'open_price': '15.050000',
#   'close_price': '15.000000',
#   'high_price': '15.050000',
#   'low_price': '14.800000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T17:40:00Z',
#   'open_price': '15.000000',
#   'close_price': '15.430000',
#   'high_price': '15.430000',
#   'low_price': '15.000000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T17:50:00Z',
#   'open_price': '15.430000',
#   'close_price': '15.480000',
#   'high_price': '15.550000',
#   'low_price': '15.430000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T18:00:00Z',
#   'open_price': '15.480000',
#   'close_price': '15.580000',
#   'high_price': '15.580000',
#   'low_price': '15.330000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T18:10:00Z',
#   'open_price': '15.580000',
#   'close_price': '15.800000',
#   'high_price': '15.830000',
#   'low_price': '15.580000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T18:20:00Z',
#   'open_price': '15.800000',
#   'close_price': '15.680000',
#   'high_price': '15.950000',
#   'low_price': '15.680000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T18:30:00Z',
#   'open_price': '15.680000',
#   'close_price': '15.700000',
#   'high_price': '15.730000',
#   'low_price': '15.300000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T18:40:00Z',
#   'open_price': '15.700000',
#   'close_price': '15.850000',
#   'high_price': '15.880000',
#   'low_price': '15.700000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T18:50:00Z',
#   'open_price': '15.850000',
#   'close_price': '15.950000',
#   'high_price': '15.950000',
#   'low_price': '15.800000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T19:00:00Z',
#   'open_price': '15.950000',
#   'close_price': '16.050000',
#   'high_price': '16.100000',
#   'low_price': '15.930000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T19:10:00Z',
#   'open_price': '16.050000',
#   'close_price': '16.200000',
#   'high_price': '16.200000',
#   'low_price': '15.980000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T19:20:00Z',
#   'open_price': '16.200000',
#   'close_price': '16.200000',
#   'high_price': '16.230000',
#   'low_price': '16.100000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T19:30:00Z',
#   'open_price': '16.200000',
#   'close_price': '16.430000',
#   'high_price': '16.430000',
#   'low_price': '16.150000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T19:40:00Z',
#   'open_price': '16.430000',
#   'close_price': '16.130000',
#   'high_price': '16.500000',
#   'low_price': '16.000000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-14T19:50:00Z',
#   'open_price': '16.130000',
#   'close_price': '16.130000',
#   'high_price': '16.150000',
#   'low_price': '16.130000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T13:30:00Z',
#   'open_price': '18.350000',
#   'close_price': '18.350000',
#   'high_price': '18.350000',
#   'low_price': '18.350000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T13:40:00Z',
#   'open_price': '18.350000',
#   'close_price': '18.730000',
#   'high_price': '18.750000',
#   'low_price': '18.350000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T13:50:00Z',
#   'open_price': '18.730000',
#   'close_price': '19.100000',
#   'high_price': '19.130000',
#   'low_price': '18.730000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T14:00:00Z',
#   'open_price': '19.100000',
#   'close_price': '18.580000',
#   'high_price': '19.130000',
#   'low_price': '18.580000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T14:10:00Z',
#   'open_price': '18.580000',
#   'close_price': '18.550000',
#   'high_price': '18.600000',
#   'low_price': '18.550000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T14:20:00Z',
#   'open_price': '18.550000',
#   'close_price': '18.400000',
#   'high_price': '18.550000',
#   'low_price': '18.350000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T14:30:00Z',
#   'open_price': '18.400000',
#   'close_price': '18.200000',
#   'high_price': '18.480000',
#   'low_price': '18.200000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T14:40:00Z',
#   'open_price': '18.200000',
#   'close_price': '18.030000',
#   'high_price': '18.200000',
#   'low_price': '18.000000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T14:50:00Z',
#   'open_price': '18.030000',
#   'close_price': '18.330000',
#   'high_price': '18.330000',
#   'low_price': '18.030000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T15:00:00Z',
#   'open_price': '18.330000',
#   'close_price': '18.680000',
#   'high_price': '18.680000',
#   'low_price': '18.330000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T15:10:00Z',
#   'open_price': '18.680000',
#   'close_price': '18.530000',
#   'high_price': '18.700000',
#   'low_price': '18.400000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T15:20:00Z',
#   'open_price': '18.530000',
#   'close_price': '18.580000',
#   'high_price': '18.600000',
#   'low_price': '18.400000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T15:30:00Z',
#   'open_price': '18.580000',
#   'close_price': '18.650000',
#   'high_price': '18.780000',
#   'low_price': '18.580000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T15:40:00Z',
#   'open_price': '18.650000',
#   'close_price': '18.480000',
#   'high_price': '18.680000',
#   'low_price': '18.400000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T15:50:00Z',
#   'open_price': '18.480000',
#   'close_price': '18.180000',
#   'high_price': '18.480000',
#   'low_price': '18.180000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T16:00:00Z',
#   'open_price': '18.180000',
#   'close_price': '17.880000',
#   'high_price': '18.180000',
#   'low_price': '17.880000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T16:10:00Z',
#   'open_price': '17.880000',
#   'close_price': '17.900000',
#   'high_price': '17.900000',
#   'low_price': '17.800000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T16:20:00Z',
#   'open_price': '17.900000',
#   'close_price': '17.780000',
#   'high_price': '17.900000',
#   'low_price': '17.680000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T16:30:00Z',
#   'open_price': '17.780000',
#   'close_price': '17.730000',
#   'high_price': '17.830000',
#   'low_price': '17.700000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T16:40:00Z',
#   'open_price': '17.730000',
#   'close_price': '17.950000',
#   'high_price': '18.000000',
#   'low_price': '17.730000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T16:50:00Z',
#   'open_price': '17.950000',
#   'close_price': '17.950000',
#   'high_price': '17.980000',
#   'low_price': '17.880000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T17:00:00Z',
#   'open_price': '17.950000',
#   'close_price': '17.830000',
#   'high_price': '18.080000',
#   'low_price': '17.800000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T17:10:00Z',
#   'open_price': '17.830000',
#   'close_price': '17.930000',
#   'high_price': '17.950000',
#   'low_price': '17.830000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T17:20:00Z',
#   'open_price': '17.930000',
#   'close_price': '17.930000',
#   'high_price': '17.950000',
#   'low_price': '17.830000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T17:30:00Z',
#   'open_price': '17.930000',
#   'close_price': '17.980000',
#   'high_price': '18.000000',
#   'low_price': '17.880000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T17:40:00Z',
#   'open_price': '17.980000',
#   'close_price': '18.180000',
#   'high_price': '18.180000',
#   'low_price': '17.950000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T17:50:00Z',
#   'open_price': '18.180000',
#   'close_price': '18.150000',
#   'high_price': '18.200000',
#   'low_price': '18.080000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T18:00:00Z',
#   'open_price': '18.150000',
#   'close_price': '17.930000',
#   'high_price': '18.150000',
#   'low_price': '17.930000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T18:10:00Z',
#   'open_price': '17.930000',
#   'close_price': '18.130000',
#   'high_price': '18.130000',
#   'low_price': '17.900000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T18:20:00Z',
#   'open_price': '18.130000',
#   'close_price': '18.180000',
#   'high_price': '18.180000',
#   'low_price': '18.050000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T18:30:00Z',
#   'open_price': '18.180000',
#   'close_price': '18.280000',
#   'high_price': '18.300000',
#   'low_price': '18.130000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T18:40:00Z',
#   'open_price': '18.280000',
#   'close_price': '18.850000',
#   'high_price': '18.850000',
#   'low_price': '18.280000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T18:50:00Z',
#   'open_price': '18.850000',
#   'close_price': '18.730000',
#   'high_price': '18.950000',
#   'low_price': '18.730000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T19:00:00Z',
#   'open_price': '18.730000',
#   'close_price': '18.350000',
#   'high_price': '18.730000',
#   'low_price': '18.280000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T19:10:00Z',
#   'open_price': '18.350000',
#   'close_price': '18.550000',
#   'high_price': '18.680000',
#   'low_price': '18.350000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T19:20:00Z',
#   'open_price': '18.550000',
#   'close_price': '18.330000',
#   'high_price': '18.550000',
#   'low_price': '18.330000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T19:30:00Z',
#   'open_price': '18.330000',
#   'close_price': '17.950000',
#   'high_price': '18.330000',
#   'low_price': '17.950000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T19:40:00Z',
#   'open_price': '17.950000',
#   'close_price': '18.130000',
#   'high_price': '18.850000',
#   'low_price': '17.950000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-15T19:50:00Z',
#   'open_price': '18.130000',
#   'close_price': '18.180000',
#   'high_price': '18.180000',
#   'low_price': '18.130000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T13:30:00Z',
#   'open_price': '20.550000',
#   'close_price': '20.550000',
#   'high_price': '20.550000',
#   'low_price': '20.550000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T13:40:00Z',
#   'open_price': '20.580000',
#   'close_price': '19.780000',
#   'high_price': '20.580000',
#   'low_price': '19.780000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T13:50:00Z',
#   'open_price': '19.780000',
#   'close_price': '20.430000',
#   'high_price': '20.450000',
#   'low_price': '19.730000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T14:00:00Z',
#   'open_price': '20.430000',
#   'close_price': '20.330000',
#   'high_price': '20.450000',
#   'low_price': '20.050000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T14:10:00Z',
#   'open_price': '20.330000',
#   'close_price': '19.980000',
#   'high_price': '20.580000',
#   'low_price': '19.980000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T14:20:00Z',
#   'open_price': '19.980000',
#   'close_price': '20.800000',
#   'high_price': '21.130000',
#   'low_price': '19.980000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T14:30:00Z',
#   'open_price': '20.800000',
#   'close_price': '20.880000',
#   'high_price': '20.900000',
#   'low_price': '20.780000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T14:40:00Z',
#   'open_price': '20.880000',
#   'close_price': '20.680000',
#   'high_price': '20.900000',
#   'low_price': '20.680000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T14:50:00Z',
#   'open_price': '20.680000',
#   'close_price': '21.230000',
#   'high_price': '21.250000',
#   'low_price': '20.680000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T15:00:00Z',
#   'open_price': '21.230000',
#   'close_price': '21.800000',
#   'high_price': '21.900000',
#   'low_price': '21.230000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T15:10:00Z',
#   'open_price': '21.800000',
#   'close_price': '21.780000',
#   'high_price': '21.850000',
#   'low_price': '21.250000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T15:20:00Z',
#   'open_price': '21.780000',
#   'close_price': '22.000000',
#   'high_price': '22.050000',
#   'low_price': '21.780000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T15:30:00Z',
#   'open_price': '22.000000',
#   'close_price': '21.850000',
#   'high_price': '22.450000',
#   'low_price': '21.850000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T15:40:00Z',
#   'open_price': '21.850000',
#   'close_price': '21.850000',
#   'high_price': '21.880000',
#   'low_price': '21.850000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T15:50:00Z',
#   'open_price': '21.850000',
#   'close_price': '21.300000',
#   'high_price': '21.880000',
#   'low_price': '21.300000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T16:00:00Z',
#   'open_price': '21.300000',
#   'close_price': '21.350000',
#   'high_price': '21.350000',
#   'low_price': '21.300000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T16:10:00Z',
#   'open_price': '21.350000',
#   'close_price': '21.480000',
#   'high_price': '21.480000',
#   'low_price': '21.350000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T16:20:00Z',
#   'open_price': '21.480000',
#   'close_price': '21.230000',
#   'high_price': '21.480000',
#   'low_price': '21.230000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T16:30:00Z',
#   'open_price': '21.230000',
#   'close_price': '20.750000',
#   'high_price': '21.230000',
#   'low_price': '20.700000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T16:40:00Z',
#   'open_price': '20.750000',
#   'close_price': '20.930000',
#   'high_price': '20.930000',
#   'low_price': '20.750000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T16:50:00Z',
#   'open_price': '20.930000',
#   'close_price': '21.100000',
#   'high_price': '21.100000',
#   'low_price': '20.930000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T17:00:00Z',
#   'open_price': '21.100000',
#   'close_price': '21.150000',
#   'high_price': '21.380000',
#   'low_price': '21.100000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T17:10:00Z',
#   'open_price': '21.150000',
#   'close_price': '20.780000',
#   'high_price': '21.150000',
#   'low_price': '20.780000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T17:20:00Z',
#   'open_price': '20.780000',
#   'close_price': '20.450000',
#   'high_price': '20.800000',
#   'low_price': '20.430000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T17:30:00Z',
#   'open_price': '20.450000',
#   'close_price': '20.600000',
#   'high_price': '20.700000',
#   'low_price': '20.450000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T17:40:00Z',
#   'open_price': '20.600000',
#   'close_price': '20.900000',
#   'high_price': '20.900000',
#   'low_price': '20.600000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T17:50:00Z',
#   'open_price': '20.900000',
#   'close_price': '21.050000',
#   'high_price': '21.280000',
#   'low_price': '20.780000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T18:00:00Z',
#   'open_price': '20.850000',
#   'close_price': '20.900000',
#   'high_price': '20.930000',
#   'low_price': '20.430000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T18:10:00Z',
#   'open_price': '20.900000',
#   'close_price': '20.950000',
#   'high_price': '20.980000',
#   'low_price': '20.880000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T18:20:00Z',
#   'open_price': '20.950000',
#   'close_price': '20.500000',
#   'high_price': '20.950000',
#   'low_price': '20.400000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T18:30:00Z',
#   'open_price': '20.500000',
#   'close_price': '20.800000',
#   'high_price': '20.800000',
#   'low_price': '20.500000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T18:40:00Z',
#   'open_price': '20.800000',
#   'close_price': '20.330000',
#   'high_price': '20.830000',
#   'low_price': '20.250000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T18:50:00Z',
#   'open_price': '20.330000',
#   'close_price': '20.330000',
#   'high_price': '20.380000',
#   'low_price': '20.330000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T19:00:00Z',
#   'open_price': '20.330000',
#   'close_price': '19.830000',
#   'high_price': '20.330000',
#   'low_price': '19.700000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T19:10:00Z',
#   'open_price': '19.830000',
#   'close_price': '20.050000',
#   'high_price': '20.050000',
#   'low_price': '19.830000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T19:20:00Z',
#   'open_price': '20.050000',
#   'close_price': '19.580000',
#   'high_price': '20.100000',
#   'low_price': '19.580000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T19:30:00Z',
#   'open_price': '19.580000',
#   'close_price': '19.330000',
#   'high_price': '19.580000',
#   'low_price': '19.330000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T19:40:00Z',
#   'open_price': '19.330000',
#   'close_price': '19.700000',
#   'high_price': '19.800000',
#   'low_price': '19.280000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-16T19:50:00Z',
#   'open_price': '19.850000',
#   'close_price': '19.330000',
#   'high_price': '19.880000',
#   'low_price': '19.330000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T13:30:00Z',
#   'open_price': '15.830000',
#   'close_price': '15.830000',
#   'high_price': '15.830000',
#   'low_price': '15.830000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T13:40:00Z',
#   'open_price': '15.830000',
#   'close_price': '15.130000',
#   'high_price': '15.850000',
#   'low_price': '15.130000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T13:50:00Z',
#   'open_price': '15.130000',
#   'close_price': '15.200000',
#   'high_price': '15.200000',
#   'low_price': '15.130000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T14:00:00Z',
#   'open_price': '15.200000',
#   'close_price': '15.700000',
#   'high_price': '15.730000',
#   'low_price': '15.200000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T14:10:00Z',
#   'open_price': '15.730000',
#   'close_price': '15.580000',
#   'high_price': '15.780000',
#   'low_price': '15.580000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T14:20:00Z',
#   'open_price': '15.580000',
#   'close_price': '15.400000',
#   'high_price': '15.600000',
#   'low_price': '15.400000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T14:30:00Z',
#   'open_price': '15.400000',
#   'close_price': '14.950000',
#   'high_price': '15.400000',
#   'low_price': '14.950000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T14:40:00Z',
#   'open_price': '14.950000',
#   'close_price': '15.230000',
#   'high_price': '15.280000',
#   'low_price': '14.950000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T14:50:00Z',
#   'open_price': '15.230000',
#   'close_price': '14.980000',
#   'high_price': '15.300000',
#   'low_price': '14.980000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T15:00:00Z',
#   'open_price': '14.980000',
#   'close_price': '15.250000',
#   'high_price': '15.250000',
#   'low_price': '14.980000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T15:10:00Z',
#   'open_price': '15.250000',
#   'close_price': '15.300000',
#   'high_price': '15.430000',
#   'low_price': '15.250000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T15:20:00Z',
#   'open_price': '15.300000',
#   'close_price': '15.300000',
#   'high_price': '15.400000',
#   'low_price': '15.200000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T15:30:00Z',
#   'open_price': '15.300000',
#   'close_price': '14.630000',
#   'high_price': '15.300000',
#   'low_price': '14.630000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T15:40:00Z',
#   'open_price': '14.630000',
#   'close_price': '14.400000',
#   'high_price': '14.650000',
#   'low_price': '14.400000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T15:50:00Z',
#   'open_price': '14.380000',
#   'close_price': '14.150000',
#   'high_price': '14.380000',
#   'low_price': '14.100000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T16:00:00Z',
#   'open_price': '14.150000',
#   'close_price': '14.230000',
#   'high_price': '14.250000',
#   'low_price': '14.080000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T16:10:00Z',
#   'open_price': '14.230000',
#   'close_price': '13.850000',
#   'high_price': '14.230000',
#   'low_price': '13.850000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T16:20:00Z',
#   'open_price': '13.850000',
#   'close_price': '13.650000',
#   'high_price': '13.850000',
#   'low_price': '13.650000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T16:30:00Z',
#   'open_price': '13.650000',
#   'close_price': '13.500000',
#   'high_price': '13.730000',
#   'low_price': '13.480000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T16:40:00Z',
#   'open_price': '13.500000',
#   'close_price': '13.330000',
#   'high_price': '13.580000',
#   'low_price': '13.280000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T16:50:00Z',
#   'open_price': '13.330000',
#   'close_price': '13.550000',
#   'high_price': '13.580000',
#   'low_price': '13.330000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T17:00:00Z',
#   'open_price': '13.550000',
#   'close_price': '13.950000',
#   'high_price': '13.950000',
#   'low_price': '13.550000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T17:10:00Z',
#   'open_price': '13.980000',
#   'close_price': '13.580000',
#   'high_price': '13.980000',
#   'low_price': '13.580000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T17:20:00Z',
#   'open_price': '13.580000',
#   'close_price': '13.530000',
#   'high_price': '13.580000',
#   'low_price': '13.430000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T17:30:00Z',
#   'open_price': '13.530000',
#   'close_price': '13.750000',
#   'high_price': '13.880000',
#   'low_price': '13.530000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T17:40:00Z',
#   'open_price': '13.750000',
#   'close_price': '13.980000',
#   'high_price': '13.980000',
#   'low_price': '13.730000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T17:50:00Z',
#   'open_price': '13.980000',
#   'close_price': '13.850000',
#   'high_price': '13.980000',
#   'low_price': '13.780000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T18:00:00Z',
#   'open_price': '13.850000',
#   'close_price': '13.780000',
#   'high_price': '13.850000',
#   'low_price': '13.750000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T18:10:00Z',
#   'open_price': '13.780000',
#   'close_price': '13.750000',
#   'high_price': '13.830000',
#   'low_price': '13.730000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T18:20:00Z',
#   'open_price': '13.750000',
#   'close_price': '13.630000',
#   'high_price': '13.780000',
#   'low_price': '13.600000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T18:30:00Z',
#   'open_price': '13.630000',
#   'close_price': '13.680000',
#   'high_price': '13.830000',
#   'low_price': '13.600000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T18:40:00Z',
#   'open_price': '13.680000',
#   'close_price': '13.730000',
#   'high_price': '13.780000',
#   'low_price': '13.650000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T18:50:00Z',
#   'open_price': '13.730000',
#   'close_price': '13.850000',
#   'high_price': '13.880000',
#   'low_price': '13.630000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T19:00:00Z',
#   'open_price': '13.850000',
#   'close_price': '13.630000',
#   'high_price': '13.850000',
#   'low_price': '13.630000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T19:10:00Z',
#   'open_price': '13.630000',
#   'close_price': '13.730000',
#   'high_price': '13.750000',
#   'low_price': '13.630000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T19:20:00Z',
#   'open_price': '13.730000',
#   'close_price': '13.530000',
#   'high_price': '13.850000',
#   'low_price': '13.530000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T19:30:00Z',
#   'open_price': '13.530000',
#   'close_price': '13.630000',
#   'high_price': '13.630000',
#   'low_price': '13.500000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T19:40:00Z',
#   'open_price': '13.630000',
#   'close_price': '13.880000',
#   'high_price': '13.950000',
#   'low_price': '13.600000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-17T19:50:00Z',
#   'open_price': '13.880000',
#   'close_price': '13.830000',
#   'high_price': '14.380000',
#   'low_price': '13.800000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T13:30:00Z',
#   'open_price': '14.380000',
#   'close_price': '14.380000',
#   'high_price': '14.380000',
#   'low_price': '14.380000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T13:40:00Z',
#   'open_price': '14.380000',
#   'close_price': '14.900000',
#   'high_price': '14.930000',
#   'low_price': '14.380000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T13:50:00Z',
#   'open_price': '14.900000',
#   'close_price': '15.530000',
#   'high_price': '15.530000',
#   'low_price': '14.900000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T14:00:00Z',
#   'open_price': '15.530000',
#   'close_price': '15.600000',
#   'high_price': '15.630000',
#   'low_price': '15.500000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T14:10:00Z',
#   'open_price': '15.600000',
#   'close_price': '15.980000',
#   'high_price': '15.980000',
#   'low_price': '15.600000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T14:20:00Z',
#   'open_price': '15.980000',
#   'close_price': '15.530000',
#   'high_price': '16.000000',
#   'low_price': '15.530000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T14:30:00Z',
#   'open_price': '15.530000',
#   'close_price': '14.950000',
#   'high_price': '15.530000',
#   'low_price': '14.950000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T14:40:00Z',
#   'open_price': '14.950000',
#   'close_price': '14.880000',
#   'high_price': '14.980000',
#   'low_price': '14.730000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T14:50:00Z',
#   'open_price': '14.880000',
#   'close_price': '14.800000',
#   'high_price': '14.900000',
#   'low_price': '14.750000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T15:00:00Z',
#   'open_price': '14.800000',
#   'close_price': '14.830000',
#   'high_price': '14.880000',
#   'low_price': '14.680000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T15:10:00Z',
#   'open_price': '14.830000',
#   'close_price': '14.330000',
#   'high_price': '14.830000',
#   'low_price': '14.330000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T15:20:00Z',
#   'open_price': '14.330000',
#   'close_price': '14.350000',
#   'high_price': '14.500000',
#   'low_price': '14.330000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T15:30:00Z',
#   'open_price': '14.350000',
#   'close_price': '13.950000',
#   'high_price': '14.350000',
#   'low_price': '13.930000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T15:40:00Z',
#   'open_price': '13.980000',
#   'close_price': '14.000000',
#   'high_price': '14.000000',
#   'low_price': '13.700000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T15:50:00Z',
#   'open_price': '14.000000',
#   'close_price': '14.130000',
#   'high_price': '14.130000',
#   'low_price': '13.950000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T16:00:00Z',
#   'open_price': '14.130000',
#   'close_price': '14.380000',
#   'high_price': '14.380000',
#   'low_price': '14.030000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T16:10:00Z',
#   'open_price': '14.380000',
#   'close_price': '14.180000',
#   'high_price': '14.480000',
#   'low_price': '14.180000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T16:20:00Z',
#   'open_price': '14.180000',
#   'close_price': '14.180000',
#   'high_price': '14.300000',
#   'low_price': '14.150000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T16:30:00Z',
#   'open_price': '14.180000',
#   'close_price': '13.800000',
#   'high_price': '14.230000',
#   'low_price': '13.800000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T16:40:00Z',
#   'open_price': '13.800000',
#   'close_price': '13.500000',
#   'high_price': '13.830000',
#   'low_price': '13.500000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T16:50:00Z',
#   'open_price': '13.500000',
#   'close_price': '13.550000',
#   'high_price': '13.580000',
#   'low_price': '13.480000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T17:00:00Z',
#   'open_price': '13.550000',
#   'close_price': '13.350000',
#   'high_price': '13.550000',
#   'low_price': '13.350000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T17:10:00Z',
#   'open_price': '13.350000',
#   'close_price': '13.430000',
#   'high_price': '13.500000',
#   'low_price': '13.330000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T17:20:00Z',
#   'open_price': '13.430000',
#   'close_price': '12.780000',
#   'high_price': '13.430000',
#   'low_price': '12.780000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T17:30:00Z',
#   'open_price': '12.780000',
#   'close_price': '12.780000',
#   'high_price': '12.900000',
#   'low_price': '12.600000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T17:40:00Z',
#   'open_price': '12.780000',
#   'close_price': '13.080000',
#   'high_price': '13.130000',
#   'low_price': '12.780000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T17:50:00Z',
#   'open_price': '13.080000',
#   'close_price': '13.300000',
#   'high_price': '13.300000',
#   'low_price': '13.050000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T18:00:00Z',
#   'open_price': '13.300000',
#   'close_price': '13.350000',
#   'high_price': '13.400000',
#   'low_price': '13.280000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T18:10:00Z',
#   'open_price': '13.350000',
#   'close_price': '13.330000',
#   'high_price': '13.530000',
#   'low_price': '13.330000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T18:20:00Z',
#   'open_price': '13.330000',
#   'close_price': '13.480000',
#   'high_price': '13.500000',
#   'low_price': '13.280000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T18:30:00Z',
#   'open_price': '13.480000',
#   'close_price': '13.650000',
#   'high_price': '13.750000',
#   'low_price': '13.480000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T18:40:00Z',
#   'open_price': '13.680000',
#   'close_price': '13.650000',
#   'high_price': '13.730000',
#   'low_price': '13.630000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T18:50:00Z',
#   'open_price': '13.650000',
#   'close_price': '13.600000',
#   'high_price': '13.650000',
#   'low_price': '13.530000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T19:00:00Z',
#   'open_price': '13.600000',
#   'close_price': '14.050000',
#   'high_price': '14.050000',
#   'low_price': '13.600000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T19:10:00Z',
#   'open_price': '14.050000',
#   'close_price': '14.330000',
#   'high_price': '14.330000',
#   'low_price': '14.050000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T19:20:00Z',
#   'open_price': '14.330000',
#   'close_price': '14.350000',
#   'high_price': '14.350000',
#   'low_price': '14.080000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T19:30:00Z',
#   'open_price': '14.350000',
#   'close_price': '14.580000',
#   'high_price': '14.580000',
#   'low_price': '14.350000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T19:40:00Z',
#   'open_price': '14.580000',
#   'close_price': '14.630000',
#   'high_price': '15.030000',
#   'low_price': '14.530000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'},
#  {'begins_at': '2020-09-18T19:50:00Z',
#   'open_price': '14.630000',
#   'close_price': '15.300000',
#   'high_price': '15.500000',
#   'low_price': '14.630000',
#   'volume': 0,
#   'session': 'reg',
#   'interpolated': False,
#   'symbol': 'ENPH'}]

# %%
#!!! fill out the specific option information
symbol = 'ENPH'
expirationDate = '2020-10-16'
strike = 55
optionType = 'call'
span = '10minute' #available options are day,week,year, and 5year
#!!!
days = 20
historicalData = r.get_option_historicals(symbol,expirationDate,strike,optionType,span)

dates = []
closingPrices = []
openPrices = []

for item in historicalData:
#     print(item)
    dates.append(dt.datetime.strptime(item['begins_at'],'%Y-%m-%dT%H:%M:%SZ'))
    closingPrices.append(float(item['close_price']))
    openPrices.append(float(item['open_price']))

# print(openPrices)
#!!! I made it so it only got the last 30 days but you could delete these lines to get full year.
dates = dates[-days:]
closingPrices = closingPrices[-days:]
openPrices = openPrices[-days:]
#
start_date = dates[0]


# change the dates into a format that matplotlib can recognize.
# x = [dt.datetime.strptime(d,'%Y-%m-%dT%H:%M:%SZ') for d in dates]
x = []
for d in dates:
    seconds = (d - start_date).total_seconds()/86400
    x.append(seconds)
    


plt.figure(figsize=(5,4))
# plots the data.
plt.plot(x, closingPrices, 'ro')
# plt.plot(x, openPrices, 'bo')
plt.title("Option price for "+r.get_name_by_symbol(symbol)+" over time")
plt.xlabel("Dates")
plt.ylabel("Price")
plt.show()

# %%
date = "2020-05-15"
tickr = "ENPH"
calls = my_trader.get_options(tickr, date, "call")
puts = my_trader.get_options(tickr, date, "put")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-2984435203d2> in <module>
#       1 date = "2020-05-15"
#       2 tickr = "ENPH"
# ----> 3 calls = my_trader.get_options(tickr, date, "call")
#       4 puts = my_trader.get_options(tickr, date, "put")
#
# AttributeError: module 'robin_stocks' has no attribute 'get_options'

# %%
idx = 12
call = calls[idx]
print(call, "\n")
put = puts[idx]
print(put, "\n")
# Out:
# {'chain_id': '53ac412e-d84f-4cd8-a239-fbbe93354dbd', 'chain_symbol': 'ENPH', 'created_at': '2020-02-11T01:10:11.123194Z', 'expiration_date': '2020-05-15', 'id': '4179a3da-7426-4be9-9614-fc0ffd803b68', 'issue_date': '2012-04-16', 'min_ticks': {'above_tick': '0.10', 'below_tick': '0.05', 'cutoff_price': '3.00'}, 'rhs_tradability': 'untradable', 'state': 'active', 'strike_price': '55.0000', 'tradability': 'tradable', 'type': 'call', 'updated_at': '2020-02-11T01:10:11.123204Z', 'url': 'https://api.robinhood.com/options/instruments/4179a3da-7426-4be9-9614-fc0ffd803b68/'}
#
# {'chain_id': '53ac412e-d84f-4cd8-a239-fbbe93354dbd', 'chain_symbol': 'ENPH', 'created_at': '2020-02-11T01:10:11.123273Z', 'expiration_date': '2020-05-15', 'id': 'f8a54abd-2916-43bb-9260-780d51e9d8b7', 'issue_date': '2012-04-16', 'min_ticks': {'above_tick': '0.10', 'below_tick': '0.05', 'cutoff_price': '3.00'}, 'rhs_tradability': 'untradable', 'state': 'active', 'strike_price': '55.0000', 'tradability': 'tradable', 'type': 'put', 'updated_at': '2020-02-11T01:10:11.123282Z', 'url': 'https://api.robinhood.com/options/instruments/f8a54abd-2916-43bb-9260-780d51e9d8b7/'}

# %%
call_data = my_trader.get_option_market_data(call["id"])
put_data = my_trader.get_option_market_data(put["id"])                                            
print(call_data, "\n\n")
print(put_data)
# Out:
# {'adjusted_mark_price': '3.700000', 'ask_price': '3.800000', 'ask_size': 60, 'bid_price': '3.600000', 'bid_size': 11, 'break_even_price': '58.700000', 'high_price': '4.100000', 'instrument': 'https://api.robinhood.com/options/instruments/4179a3da-7426-4be9-9614-fc0ffd803b68/', 'last_trade_price': '3.700000', 'last_trade_size': 2, 'low_price': '2.150000', 'mark_price': '3.700000', 'open_interest': 1669, 'previous_close_date': '2020-05-07', 'previous_close_price': '2.280000', 'volume': 432, 'chance_of_profit_long': '0.388735', 'chance_of_profit_short': '0.611265', 'delta': '0.667985', 'gamma': '0.059409', 'implied_volatility': '0.770342', 'rho': '0.006628', 'theta': '-0.158596', 'vega': '0.028797', 'high_fill_rate_buy_price': '3.760000', 'high_fill_rate_sell_price': '3.610000', 'low_fill_rate_buy_price': '3.680000', 'low_fill_rate_sell_price': '3.700000'}
#
#
# {'adjusted_mark_price': '1.450000', 'ask_price': '1.500000', 'ask_size': 11, 'bid_price': '1.400000', 'bid_size': 10, 'break_even_price': '53.550000', 'high_price': '2.700000', 'instrument': 'https://api.robinhood.com/options/instruments/f8a54abd-2916-43bb-9260-780d51e9d8b7/', 'last_trade_price': '1.410000', 'last_trade_size': 1, 'low_price': '1.350000', 'mark_price': '1.450000', 'open_interest': 1391, 'previous_close_date': '2020-05-07', 'previous_close_price': '3.030000', 'volume': 386, 'chance_of_profit_long': '0.284846', 'chance_of_profit_short': '0.715154', 'delta': '-0.333681', 'gamma': '0.058692', 'implied_volatility': '0.781298', 'rho': '-0.003944', 'theta': '-0.160942', 'vega': '0.028854', 'high_fill_rate_buy_price': '1.490000', 'high_fill_rate_sell_price': '1.410000', 'low_fill_rate_buy_price': '1.440000', 'low_fill_rate_sell_price': '1.460000'}

# %%
C = float(call_data["adjusted_mark_price"])
S = 
T = 11/365
bren_subra_approx(T, C, S)
# Out:
# 0.6634179548215633

# %%
# Calculate IV or sigma various methods

# Use Brenes and Subrahmanyam approximation
def bren_subra_approx (time, option_price, stock_price):
    iv = (math.sqrt(2*math.pi/time))*(option_price/stock_price)
    return iv

# %%
my_trader.get_historical_quotes(tickr, "day", "week")
# my_trader.quote_data("TSLA")
# Out:
# {'results': [{'quote': 'https://api.robinhood.com/quotes/69cbc174-ead1-49a9-9c72-a8f015de474f/',
#    'symbol': 'ENPH',
#    'interval': 'day',
#    'span': 'week',
#    'bounds': 'regular',
#    'instrument': 'https://api.robinhood.com/instruments/69cbc174-ead1-49a9-9c72-a8f015de474f/',
#    'historicals': [{'begins_at': '2020-05-04T00:00:00Z',
#      'open_price': '41.750000',
#      'close_price': '43.980000',
#      'high_price': '44.150000',
#      'low_price': '41.570000',
#      'volume': 3294538,
#      'session': 'reg',
#      'interpolated': False},
#     {'begins_at': '2020-05-05T00:00:00Z',
#      'open_price': '46.330000',
#      'close_price': '44.370000',
#      'high_price': '46.500000',
#      'low_price': '43.790000',
#      'volume': 5430121,
#      'session': 'reg',
#      'interpolated': False},
#     {'begins_at': '2020-05-06T00:00:00Z',
#      'open_price': '47.000000',
#      'close_price': '52.680000',
#      'high_price': '53.530000',
#      'low_price': '46.500000',
#      'volume': 11216009,
#      'session': 'reg',
#      'interpolated': False},
#     {'begins_at': '2020-05-07T00:00:00Z',
#      'open_price': '52.560000',
#      'close_price': '54.490000',
#      'high_price': '55.880000',
#      'low_price': '50.560000',
#      'volume': 8124638,
#      'session': 'reg',
#      'interpolated': False},
#     {'begins_at': '2020-05-08T00:00:00Z',
#      'open_price': '55.740000',
#      'close_price': '57.280000',
#      'high_price': '57.842800',
#      'low_price': '54.370000',
#      'volume': 4426249,
#      'session': 'reg',
#      'interpolated': False}],
#    'InstrumentID': '69cbc174-ead1-49a9-9c72-a8f015de474f'}]}

# %%
tickr = "AMZN"
# my_trader.get_news(tickr)

# %%
# my_trader.positions()
stock_instrument = my_trader.instruments("GEVO")[0]
# stock_instrument

# %%
url = str("https://api.robinhood.com/options/instruments/4179a3da-7426-4be9-9614-fc0ffd803b68/")
buy_order = my_trader.place_market_buy_order(url, symbol='ENPH', time_in_force ='GFD', quantity=1)
# Out:
# {'account': 'https://api.robinhood.com/accounts/5XD84262/', 'instrument': 'https://api.robinhood.com/options/instruments/4179a3da-7426-4be9-9614-fc0ffd803b68/', 'symbol': 'ENPH', 'type': 'market', 'time_in_force': 'gfd', 'trigger': 'immediate', 'price': 57.49, 'quantity': 1, 'side': 'buy'}
# 400 Client Error: Bad Request for url: https://api.robinhood.com/orders/
