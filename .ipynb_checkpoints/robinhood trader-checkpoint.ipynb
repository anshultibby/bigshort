# %%
import robin_stocks as r
import inspect
import math
import matplotlib.pyplot as plt
import datetime as dt
import yfinance
import numpy as np

# %%
my_trader = r
my_trader.login(username="anshul.tibrewal2203@gmail.com", password="Icangeta45!")
bs = "bs"

# %%
r.options.get_chains("ENPH")
# Out:
# {'id': '53ac412e-d84f-4cd8-a239-fbbe93354dbd',
#  'symbol': 'ENPH',
#  'can_open_position': True,
#  'cash_component': None,
#  'expiration_dates': ['2020-11-20',
#   '2020-12-18',
#   '2021-01-15',
#   '2021-02-19',
#   '2021-05-21',
#   '2022-01-21',
#   '2023-01-20'],
#  'trade_value_multiplier': '100.0000',
#  'underlying_instruments': [{'id': 'b3bb1a74-ee77-4442-8f71-566fa5a2c705',
#    'instrument': 'https://api.robinhood.com/instruments/69cbc174-ead1-49a9-9c72-a8f015de474f/',
#    'quantity': 100}],
#  'min_ticks': {'above_tick': '0.05',
#   'below_tick': '0.01',
#   'cutoff_price': '3.00'}}

# %%
#!!! fill out the specific option information
symbol = 'ENPH'
expirationDate = '2020-11-20'
strike = 55
optionType = 'call'
span = '10minute' #available options are day,week,year, and 5year
#!!!
days = 20
historicalData = r.get_option_historicals(symbol,expirationDate,strike,optionType,span)

dates = []
closingPrices = []
openPrices = []

for item in historicalData:
#     print(item)
    dates.append(dt.datetime.strptime(item['begins_at'],'%Y-%m-%dT%H:%M:%SZ'))
    closingPrices.append(float(item['close_price']))
    openPrices.append(float(item['open_price']))

# print(openPrices)
#!!! I made it so it only got the last 30 days but you could delete these lines to get full year.
dates = dates[-days:]
closingPrices = closingPrices[-days:]
openPrices = openPrices[-days:]
#
start_date = dates[0]


# change the dates into a format that matplotlib can recognize.
# x = [dt.datetime.strptime(d,'%Y-%m-%dT%H:%M:%SZ') for d in dates]
x = []
for d in dates:
    seconds = (d - start_date).total_seconds()/86400
    x.append(seconds)
    


plt.figure(figsize=(5,4))
# plots the data.
plt.plot(x, closingPrices, 'ro')
# plt.plot(x, openPrices, 'bo')
plt.title("Option price for "+r.get_name_by_symbol(symbol)+" over time")
plt.xlabel("Dates")
plt.ylabel("Price")
plt.show()

# %%
date = "2020-05-15"
tickr = "ENPH"
calls = my_trader.get_options(tickr, date, "call")
puts = my_trader.get_options(tickr, date, "put")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-2984435203d2> in <module>
#       1 date = "2020-05-15"
#       2 tickr = "ENPH"
# ----> 3 calls = my_trader.get_options(tickr, date, "call")
#       4 puts = my_trader.get_options(tickr, date, "put")
#
# AttributeError: module 'robin_stocks' has no attribute 'get_options'

# %%
idx = 12
call = calls[idx]
print(call, "\n")
put = puts[idx]
print(put, "\n")
# Out:
# {'chain_id': '53ac412e-d84f-4cd8-a239-fbbe93354dbd', 'chain_symbol': 'ENPH', 'created_at': '2020-02-11T01:10:11.123194Z', 'expiration_date': '2020-05-15', 'id': '4179a3da-7426-4be9-9614-fc0ffd803b68', 'issue_date': '2012-04-16', 'min_ticks': {'above_tick': '0.10', 'below_tick': '0.05', 'cutoff_price': '3.00'}, 'rhs_tradability': 'untradable', 'state': 'active', 'strike_price': '55.0000', 'tradability': 'tradable', 'type': 'call', 'updated_at': '2020-02-11T01:10:11.123204Z', 'url': 'https://api.robinhood.com/options/instruments/4179a3da-7426-4be9-9614-fc0ffd803b68/'}
#
# {'chain_id': '53ac412e-d84f-4cd8-a239-fbbe93354dbd', 'chain_symbol': 'ENPH', 'created_at': '2020-02-11T01:10:11.123273Z', 'expiration_date': '2020-05-15', 'id': 'f8a54abd-2916-43bb-9260-780d51e9d8b7', 'issue_date': '2012-04-16', 'min_ticks': {'above_tick': '0.10', 'below_tick': '0.05', 'cutoff_price': '3.00'}, 'rhs_tradability': 'untradable', 'state': 'active', 'strike_price': '55.0000', 'tradability': 'tradable', 'type': 'put', 'updated_at': '2020-02-11T01:10:11.123282Z', 'url': 'https://api.robinhood.com/options/instruments/f8a54abd-2916-43bb-9260-780d51e9d8b7/'}

# %%
call_data = my_trader.get_option_market_data(call["id"])
put_data = my_trader.get_option_market_data(put["id"])                                            
print(call_data, "\n\n")
print(put_data)
# Out:
# {'adjusted_mark_price': '3.700000', 'ask_price': '3.800000', 'ask_size': 60, 'bid_price': '3.600000', 'bid_size': 11, 'break_even_price': '58.700000', 'high_price': '4.100000', 'instrument': 'https://api.robinhood.com/options/instruments/4179a3da-7426-4be9-9614-fc0ffd803b68/', 'last_trade_price': '3.700000', 'last_trade_size': 2, 'low_price': '2.150000', 'mark_price': '3.700000', 'open_interest': 1669, 'previous_close_date': '2020-05-07', 'previous_close_price': '2.280000', 'volume': 432, 'chance_of_profit_long': '0.388735', 'chance_of_profit_short': '0.611265', 'delta': '0.667985', 'gamma': '0.059409', 'implied_volatility': '0.770342', 'rho': '0.006628', 'theta': '-0.158596', 'vega': '0.028797', 'high_fill_rate_buy_price': '3.760000', 'high_fill_rate_sell_price': '3.610000', 'low_fill_rate_buy_price': '3.680000', 'low_fill_rate_sell_price': '3.700000'}
#
#
# {'adjusted_mark_price': '1.450000', 'ask_price': '1.500000', 'ask_size': 11, 'bid_price': '1.400000', 'bid_size': 10, 'break_even_price': '53.550000', 'high_price': '2.700000', 'instrument': 'https://api.robinhood.com/options/instruments/f8a54abd-2916-43bb-9260-780d51e9d8b7/', 'last_trade_price': '1.410000', 'last_trade_size': 1, 'low_price': '1.350000', 'mark_price': '1.450000', 'open_interest': 1391, 'previous_close_date': '2020-05-07', 'previous_close_price': '3.030000', 'volume': 386, 'chance_of_profit_long': '0.284846', 'chance_of_profit_short': '0.715154', 'delta': '-0.333681', 'gamma': '0.058692', 'implied_volatility': '0.781298', 'rho': '-0.003944', 'theta': '-0.160942', 'vega': '0.028854', 'high_fill_rate_buy_price': '1.490000', 'high_fill_rate_sell_price': '1.410000', 'low_fill_rate_buy_price': '1.440000', 'low_fill_rate_sell_price': '1.460000'}

# %%
C = float(call_data["adjusted_mark_price"])
S = 
T = 11/365
bren_subra_approx(T, C, S)
# Out:
# 0.6634179548215633

# %%
# Calculate IV or sigma various methods

# Use Brenes and Subrahmanyam approximation
def bren_subra_approx (time, option_price, stock_price):
    iv = (math.sqrt(2*math.pi/time))*(option_price/stock_price)
    return iv

# %%
my_trader.get_historical_quotes(tickr, "day", "week")
# my_trader.quote_data("TSLA")
# Out:
# {'results': [{'quote': 'https://api.robinhood.com/quotes/69cbc174-ead1-49a9-9c72-a8f015de474f/',
#    'symbol': 'ENPH',
#    'interval': 'day',
#    'span': 'week',
#    'bounds': 'regular',
#    'instrument': 'https://api.robinhood.com/instruments/69cbc174-ead1-49a9-9c72-a8f015de474f/',
#    'historicals': [{'begins_at': '2020-05-04T00:00:00Z',
#      'open_price': '41.750000',
#      'close_price': '43.980000',
#      'high_price': '44.150000',
#      'low_price': '41.570000',
#      'volume': 3294538,
#      'session': 'reg',
#      'interpolated': False},
#     {'begins_at': '2020-05-05T00:00:00Z',
#      'open_price': '46.330000',
#      'close_price': '44.370000',
#      'high_price': '46.500000',
#      'low_price': '43.790000',
#      'volume': 5430121,
#      'session': 'reg',
#      'interpolated': False},
#     {'begins_at': '2020-05-06T00:00:00Z',
#      'open_price': '47.000000',
#      'close_price': '52.680000',
#      'high_price': '53.530000',
#      'low_price': '46.500000',
#      'volume': 11216009,
#      'session': 'reg',
#      'interpolated': False},
#     {'begins_at': '2020-05-07T00:00:00Z',
#      'open_price': '52.560000',
#      'close_price': '54.490000',
#      'high_price': '55.880000',
#      'low_price': '50.560000',
#      'volume': 8124638,
#      'session': 'reg',
#      'interpolated': False},
#     {'begins_at': '2020-05-08T00:00:00Z',
#      'open_price': '55.740000',
#      'close_price': '57.280000',
#      'high_price': '57.842800',
#      'low_price': '54.370000',
#      'volume': 4426249,
#      'session': 'reg',
#      'interpolated': False}],
#    'InstrumentID': '69cbc174-ead1-49a9-9c72-a8f015de474f'}]}

# %%
tickr = "AMZN"
# my_trader.get_news(tickr)

# %%
# my_trader.positions()
stock_instrument = my_trader.instruments("GEVO")[0]
# stock_instrument

# %%
url = str("https://api.robinhood.com/options/instruments/4179a3da-7426-4be9-9614-fc0ffd803b68/")
buy_order = my_trader.place_market_buy_order(url, symbol='ENPH', time_in_force ='GFD', quantity=1)
# Out:
# {'account': 'https://api.robinhood.com/accounts/5XD84262/', 'instrument': 'https://api.robinhood.com/options/instruments/4179a3da-7426-4be9-9614-fc0ffd803b68/', 'symbol': 'ENPH', 'type': 'market', 'time_in_force': 'gfd', 'trigger': 'immediate', 'price': 57.49, 'quantity': 1, 'side': 'buy'}
# 400 Client Error: Bad Request for url: https://api.robinhood.com/orders/

# %%
def find_weekly_movement(symbol, interval="week", span="3month"):
    history = r.stocks.get_stock_historicals(symbol, interval, span)
    moves = []
    for i, h in enumerate(history):
        if i == 0:
            opening = h["open_price"]
        else:
            opening = closing
            
        closing = h["close_price"]
        move = float(closing) - float(opening)
        moves.append(move)

    return np.mean(moves), np.std(moves), np.sum(moves)

# %%
find_weekly_movement(symbol, interval="week", span="3month")
# Out:
# (2.4223076923076925, 3.3862917177397973, 31.490000000000002)

# %% [markdown]
# # Find calendar debit spread profit potentials

# %%
# indentify a stock
symbol = "nio"
duration = 1 # how many option expiries in between calendar
avg_move, std_move, _ = find_weekly_movement(symbol, interval="week", span="month")
price_search = math.ceil(avg_move + std_move)

# get current stock price
price = float(r.stocks.get_latest_price(symbol)[0])

# get relevant chains
chains = r.options.get_chains(symbol)
expirations = chains["expiration_dates"]

# select buy and sell orders for debit spread
buy = r.options.find_tradable_options(symbol, expirations[duration], optionType="call")
print(f"Buy call for {expirations[duration]}")
sell = r.options.find_tradable_options(symbol, expirations[0], optionType="call")
print(f"Sell call for {expirations[0]}")
# Out:
# Buy call for 2020-11-27
# Found Additional pages.
# Loading page 2 ...
# Sell call for 2020-11-20

# %%
# list viable options defined by price search param
viable_buy = []
strikes = []
viable_sell = []
for option in buy:
    strike = float(option["strike_price"])
    if (price - price_search) <= strike <= (price + price_search):
        strikes.append(strike)
        viable_buy.append(option)
        
for option in sell:
    strike = float(option["strike_price"])
    if (price - price_search) <= strike <= (price + price_search):
        strikes.append(strike)
        viable_sell.append(option)

# %%
print(len(buy), len(viable_buy), len(sell), len(viable_sell))
buy[0]
# Out:
# 73 18 102 29
# {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#  'chain_symbol': 'NIO',
#  'created_at': '2020-11-14T02:14:26.403867Z',
#  'expiration_date': '2020-11-27',
#  'id': '5c3c7fd0-c56e-48c1-9eb4-07a4a0cde71b',
#  'issue_date': '2018-09-18',
#  'min_ticks': {'above_tick': '0.05',
#   'below_tick': '0.01',
#   'cutoff_price': '3.00'},
#  'rhs_tradability': 'untradable',
#  'state': 'active',
#  'strike_price': '80.0000',
#  'tradability': 'tradable',
#  'type': 'call',
#  'updated_at': '2020-11-14T02:14:26.403873Z',
#  'url': 'https://api.robinhood.com/options/instruments/5c3c7fd0-c56e-48c1-9eb4-07a4a0cde71b/',
#  'sellout_datetime': '2020-11-27T17:00:00+00:00'}

# %%
buy
# Out:
# [{'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-14T02:14:26.403867Z',
#   'expiration_date': '2020-11-27',
#   'id': '5c3c7fd0-c56e-48c1-9eb4-07a4a0cde71b',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '80.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-14T02:14:26.403873Z',
#   'url': 'https://api.robinhood.com/options/instruments/5c3c7fd0-c56e-48c1-9eb4-07a4a0cde71b/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-14T02:14:26.403775Z',
#   'expiration_date': '2020-11-27',
#   'id': '06b64d49-c9ae-4791-889f-86f8f17ffa32',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '75.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-14T02:14:26.403782Z',
#   'url': 'https://api.robinhood.com/options/instruments/06b64d49-c9ae-4791-889f-86f8f17ffa32/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-13T01:04:36.498679Z',
#   'expiration_date': '2020-11-27',
#   'id': '534efb8d-9b89-447a-be16-c6b6de260d6f',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '67.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-13T01:04:36.498686Z',
#   'url': 'https://api.robinhood.com/options/instruments/534efb8d-9b89-447a-be16-c6b6de260d6f/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-13T01:04:36.498632Z',
#   'expiration_date': '2020-11-27',
#   'id': 'ab8f6ef1-8217-44ef-932a-ce01fd5d025d',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '68.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-13T01:04:36.498639Z',
#   'url': 'https://api.robinhood.com/options/instruments/ab8f6ef1-8217-44ef-932a-ce01fd5d025d/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-13T01:04:36.498537Z',
#   'expiration_date': '2020-11-27',
#   'id': '59b3a9e2-10ae-4a76-b303-d1d423776424',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '69.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-13T01:04:36.498544Z',
#   'url': 'https://api.robinhood.com/options/instruments/59b3a9e2-10ae-4a76-b303-d1d423776424/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-13T01:04:36.498387Z',
#   'expiration_date': '2020-11-27',
#   'id': '9c820db7-f829-4be9-98ec-33357c4f2b4f',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '66.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-13T01:04:36.498394Z',
#   'url': 'https://api.robinhood.com/options/instruments/9c820db7-f829-4be9-98ec-33357c4f2b4f/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-13T01:04:36.497770Z',
#   'expiration_date': '2020-11-27',
#   'id': '6f34f05e-edca-4e04-87aa-82fc764fc793',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '70.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-13T01:04:36.497777Z',
#   'url': 'https://api.robinhood.com/options/instruments/6f34f05e-edca-4e04-87aa-82fc764fc793/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-10T02:06:00.068290Z',
#   'expiration_date': '2020-11-27',
#   'id': '017fc802-6acf-492a-833e-b2d09dc8c797',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '65.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-10T02:06:00.068297Z',
#   'url': 'https://api.robinhood.com/options/instruments/017fc802-6acf-492a-833e-b2d09dc8c797/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-07T01:14:36.283332Z',
#   'expiration_date': '2020-11-27',
#   'id': '007a50e9-8d2b-43bb-b0d8-f294f01d06c6',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '63.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-07T01:14:36.283339Z',
#   'url': 'https://api.robinhood.com/options/instruments/007a50e9-8d2b-43bb-b0d8-f294f01d06c6/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-07T01:14:36.283285Z',
#   'expiration_date': '2020-11-27',
#   'id': 'a7e1caf5-3264-48d5-85e8-376cb319f9dd',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '61.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-07T01:14:36.283292Z',
#   'url': 'https://api.robinhood.com/options/instruments/a7e1caf5-3264-48d5-85e8-376cb319f9dd/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-07T01:14:36.283100Z',
#   'expiration_date': '2020-11-27',
#   'id': 'f08c6062-7113-4691-8368-4a7a27801849',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '62.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-07T01:14:36.283106Z',
#   'url': 'https://api.robinhood.com/options/instruments/f08c6062-7113-4691-8368-4a7a27801849/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-07T01:14:36.282856Z',
#   'expiration_date': '2020-11-27',
#   'id': 'e4655d10-66e4-483f-8f03-aa3fb78dfd03',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '64.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-07T01:14:36.282863Z',
#   'url': 'https://api.robinhood.com/options/instruments/e4655d10-66e4-483f-8f03-aa3fb78dfd03/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-06T01:03:57.433344Z',
#   'expiration_date': '2020-11-27',
#   'id': '54698167-5b75-4daa-a749-56cb2a910ae9',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '58.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-06T01:03:57.433351Z',
#   'url': 'https://api.robinhood.com/options/instruments/54698167-5b75-4daa-a749-56cb2a910ae9/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-06T01:03:57.433299Z',
#   'expiration_date': '2020-11-27',
#   'id': '79608605-b790-4ec7-831b-1c0c65704417',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '56.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-06T01:03:57.433306Z',
#   'url': 'https://api.robinhood.com/options/instruments/79608605-b790-4ec7-831b-1c0c65704417/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-06T01:03:57.433210Z',
#   'expiration_date': '2020-11-27',
#   'id': '21d3329c-1e63-47dd-8b6b-ee34c8738969',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '59.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-06T01:03:57.433216Z',
#   'url': 'https://api.robinhood.com/options/instruments/21d3329c-1e63-47dd-8b6b-ee34c8738969/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-06T01:03:57.433077Z',
#   'expiration_date': '2020-11-27',
#   'id': 'e750c50f-ce0b-4e7e-ab16-8c07243dcece',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '60.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-06T01:03:57.433083Z',
#   'url': 'https://api.robinhood.com/options/instruments/e750c50f-ce0b-4e7e-ab16-8c07243dcece/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-06T01:03:57.432930Z',
#   'expiration_date': '2020-11-27',
#   'id': '00a2b3d4-3579-42dd-a5b0-7da054c50d1b',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '57.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-06T01:03:57.432936Z',
#   'url': 'https://api.robinhood.com/options/instruments/00a2b3d4-3579-42dd-a5b0-7da054c50d1b/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-06T01:03:57.431945Z',
#   'expiration_date': '2020-11-27',
#   'id': '41457f13-86ae-4574-bcbb-bb261b82b4e8',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '54.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-06T01:03:57.431952Z',
#   'url': 'https://api.robinhood.com/options/instruments/41457f13-86ae-4574-bcbb-bb261b82b4e8/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-05T02:08:26.717310Z',
#   'expiration_date': '2020-11-27',
#   'id': '55327ef4-6e9c-4ef7-9ab6-c3ad123f9fd9',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '55.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-05T02:08:26.717317Z',
#   'url': 'https://api.robinhood.com/options/instruments/55327ef4-6e9c-4ef7-9ab6-c3ad123f9fd9/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-04T03:02:46.624539Z',
#   'expiration_date': '2020-11-27',
#   'id': '267467d8-2567-4ccc-8159-592a36e4b9b9',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '53.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-04T03:02:46.624546Z',
#   'url': 'https://api.robinhood.com/options/instruments/267467d8-2567-4ccc-8159-592a36e4b9b9/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-04T03:02:46.624447Z',
#   'expiration_date': '2020-11-27',
#   'id': 'cb609594-1e59-4237-8774-194d205413b3',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '52.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-04T03:02:46.624454Z',
#   'url': 'https://api.robinhood.com/options/instruments/cb609594-1e59-4237-8774-194d205413b3/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-04T03:02:46.624355Z',
#   'expiration_date': '2020-11-27',
#   'id': '5f23972e-fddf-4da4-b829-d1f112d6bf9c',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '51.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-04T03:02:46.624362Z',
#   'url': 'https://api.robinhood.com/options/instruments/5f23972e-fddf-4da4-b829-d1f112d6bf9c/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-04T03:02:46.624263Z',
#   'expiration_date': '2020-11-27',
#   'id': 'fe47e526-d501-4518-8b44-0af40d1889f2',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '49.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-04T03:02:46.624270Z',
#   'url': 'https://api.robinhood.com/options/instruments/fe47e526-d501-4518-8b44-0af40d1889f2/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-04T03:02:46.624172Z',
#   'expiration_date': '2020-11-27',
#   'id': '4e4550ef-6102-49ef-b43a-6db27c253765',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '48.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-04T03:02:46.624178Z',
#   'url': 'https://api.robinhood.com/options/instruments/4e4550ef-6102-49ef-b43a-6db27c253765/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-04T03:02:46.624080Z',
#   'expiration_date': '2020-11-27',
#   'id': '98af7d95-a3d2-4fcc-a665-dfb37866d1bd',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '47.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-04T03:02:46.624086Z',
#   'url': 'https://api.robinhood.com/options/instruments/98af7d95-a3d2-4fcc-a665-dfb37866d1bd/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-04T03:02:46.623987Z',
#   'expiration_date': '2020-11-27',
#   'id': '5d64f03e-c5df-45b1-9a47-6a2f78171018',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '46.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-04T03:02:46.623994Z',
#   'url': 'https://api.robinhood.com/options/instruments/5d64f03e-c5df-45b1-9a47-6a2f78171018/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-11-04T03:02:46.621901Z',
#   'expiration_date': '2020-11-27',
#   'id': '8c974ab2-c12e-4cd2-9ab6-ff092af8aacb',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '50.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-11-04T03:02:46.621908Z',
#   'url': 'https://api.robinhood.com/options/instruments/8c974ab2-c12e-4cd2-9ab6-ff092af8aacb/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-31T05:49:55.963720Z',
#   'expiration_date': '2020-11-27',
#   'id': '930aa500-b5dc-45e2-9bae-40e461446eb1',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '45.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-31T05:49:55.963730Z',
#   'url': 'https://api.robinhood.com/options/instruments/930aa500-b5dc-45e2-9bae-40e461446eb1/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-30T05:22:00.029224Z',
#   'expiration_date': '2020-11-27',
#   'id': 'd4a73d1a-3221-44c8-b095-7a601998e284',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '44.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-30T05:22:00.029230Z',
#   'url': 'https://api.robinhood.com/options/instruments/d4a73d1a-3221-44c8-b095-7a601998e284/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-16T00:05:04.412652Z',
#   'expiration_date': '2020-11-27',
#   'id': '2790308f-07e0-4642-9998-f2d3d5080492',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '42.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-16T00:05:04.412659Z',
#   'url': 'https://api.robinhood.com/options/instruments/2790308f-07e0-4642-9998-f2d3d5080492/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-16T00:05:04.411608Z',
#   'expiration_date': '2020-11-27',
#   'id': 'ac1562f4-dbc9-4f39-a5ee-faafc886ec45',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '43.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-16T00:05:04.411615Z',
#   'url': 'https://api.robinhood.com/options/instruments/ac1562f4-dbc9-4f39-a5ee-faafc886ec45/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-16T00:05:04.411514Z',
#   'expiration_date': '2020-11-27',
#   'id': 'dfb5156b-be0b-4a05-8056-b48d06a4e117',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '41.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-16T00:05:04.411521Z',
#   'url': 'https://api.robinhood.com/options/instruments/dfb5156b-be0b-4a05-8056-b48d06a4e117/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-15T07:16:40.918143Z',
#   'expiration_date': '2020-11-27',
#   'id': '52ca7fab-284d-4ff3-a5d3-542e447970eb',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '34.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-15T07:16:40.918149Z',
#   'url': 'https://api.robinhood.com/options/instruments/52ca7fab-284d-4ff3-a5d3-542e447970eb/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-15T07:16:40.918098Z',
#   'expiration_date': '2020-11-27',
#   'id': '15bd186f-8fe0-47fe-ba33-44156781c4c3',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '35.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-15T07:16:40.918105Z',
#   'url': 'https://api.robinhood.com/options/instruments/15bd186f-8fe0-47fe-ba33-44156781c4c3/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-15T07:16:40.914748Z',
#   'expiration_date': '2020-11-27',
#   'id': '44cfad17-2a38-424f-aadc-209c1b2409c8',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '39.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-15T07:16:40.914755Z',
#   'url': 'https://api.robinhood.com/options/instruments/44cfad17-2a38-424f-aadc-209c1b2409c8/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-15T07:16:40.912936Z',
#   'expiration_date': '2020-11-27',
#   'id': '49506720-d283-401b-9811-1de26be91970',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '36.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-15T07:16:40.912943Z',
#   'url': 'https://api.robinhood.com/options/instruments/49506720-d283-401b-9811-1de26be91970/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-15T07:16:40.912891Z',
#   'expiration_date': '2020-11-27',
#   'id': '8f41a051-c012-4519-81b5-92ca50044b01',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '37.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-15T07:16:40.912897Z',
#   'url': 'https://api.robinhood.com/options/instruments/8f41a051-c012-4519-81b5-92ca50044b01/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-15T07:16:40.912520Z',
#   'expiration_date': '2020-11-27',
#   'id': '5e1c028a-845a-4684-b6c9-5c2b029f10f3',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '38.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-15T07:16:40.912526Z',
#   'url': 'https://api.robinhood.com/options/instruments/5e1c028a-845a-4684-b6c9-5c2b029f10f3/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-15T07:16:40.910581Z',
#   'expiration_date': '2020-11-27',
#   'id': '498add4d-3f9e-4088-9cbe-e42caab32dd7',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '40.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-15T07:16:40.910587Z',
#   'url': 'https://api.robinhood.com/options/instruments/498add4d-3f9e-4088-9cbe-e42caab32dd7/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-09T01:06:47.702085Z',
#   'expiration_date': '2020-11-27',
#   'id': '4c3495db-2f5e-4daa-9bff-2e5d6bdd1697',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '14.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-09T01:06:47.702091Z',
#   'url': 'https://api.robinhood.com/options/instruments/4c3495db-2f5e-4daa-9bff-2e5d6bdd1697/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-09T01:06:47.702039Z',
#   'expiration_date': '2020-11-27',
#   'id': '78d3f811-2ca6-4f45-a280-64a57f85abff',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '31.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-09T01:06:47.702045Z',
#   'url': 'https://api.robinhood.com/options/instruments/78d3f811-2ca6-4f45-a280-64a57f85abff/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-09T01:06:47.701993Z',
#   'expiration_date': '2020-11-27',
#   'id': 'e0b943e7-557c-47fc-93b5-d814e8f8ec76',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '33.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-09T01:06:47.701999Z',
#   'url': 'https://api.robinhood.com/options/instruments/e0b943e7-557c-47fc-93b5-d814e8f8ec76/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-09T01:06:47.701856Z',
#   'expiration_date': '2020-11-27',
#   'id': '22ed0ae5-15d6-4ec2-8aee-20c16515b38b',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '29.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-09T01:06:47.701862Z',
#   'url': 'https://api.robinhood.com/options/instruments/22ed0ae5-15d6-4ec2-8aee-20c16515b38b/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-09T01:06:47.701810Z',
#   'expiration_date': '2020-11-27',
#   'id': 'ae731a34-dfa7-4e96-a109-d2542e672b45',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '30.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-09T01:06:47.701817Z',
#   'url': 'https://api.robinhood.com/options/instruments/ae731a34-dfa7-4e96-a109-d2542e672b45/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-09T01:06:47.701719Z',
#   'expiration_date': '2020-11-27',
#   'id': 'c2b44ced-8c74-40d6-83bb-ecfa48caac30',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '12.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-09T01:06:47.701725Z',
#   'url': 'https://api.robinhood.com/options/instruments/c2b44ced-8c74-40d6-83bb-ecfa48caac30/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-09T01:06:47.701534Z',
#   'expiration_date': '2020-11-27',
#   'id': 'dc1cba6b-aadb-4d19-9f35-13d02dda80eb',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '32.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-09T01:06:47.701541Z',
#   'url': 'https://api.robinhood.com/options/instruments/dc1cba6b-aadb-4d19-9f35-13d02dda80eb/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-09T01:06:47.701488Z',
#   'expiration_date': '2020-11-27',
#   'id': 'cf8ad2a9-14e7-4e01-98f0-d4c0c0b64a0a',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '13.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-09T01:06:47.701494Z',
#   'url': 'https://api.robinhood.com/options/instruments/cf8ad2a9-14e7-4e01-98f0-d4c0c0b64a0a/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.912101Z',
#   'expiration_date': '2020-11-27',
#   'id': '9bfa8ced-fcac-4e24-80de-0e3863e0ea2b',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '17.5000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.912107Z',
#   'url': 'https://api.robinhood.com/options/instruments/9bfa8ced-fcac-4e24-80de-0e3863e0ea2b/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.912009Z',
#   'expiration_date': '2020-11-27',
#   'id': '8d9ef9d2-9014-4d9e-b61d-69b7a615e5bd',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '16.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.912016Z',
#   'url': 'https://api.robinhood.com/options/instruments/8d9ef9d2-9014-4d9e-b61d-69b7a615e5bd/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.911872Z',
#   'expiration_date': '2020-11-27',
#   'id': '29f590aa-bff7-4e36-9c99-93745f6caa4e',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '25.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.911879Z',
#   'url': 'https://api.robinhood.com/options/instruments/29f590aa-bff7-4e36-9c99-93745f6caa4e/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.911826Z',
#   'expiration_date': '2020-11-27',
#   'id': 'ce6739b9-6676-4031-8e53-abeffb60008a',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '16.5000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.911833Z',
#   'url': 'https://api.robinhood.com/options/instruments/ce6739b9-6676-4031-8e53-abeffb60008a/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.911641Z',
#   'expiration_date': '2020-11-27',
#   'id': '2258d526-e4d8-4721-a7a4-ea5aa3d9b4cc',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '25.5000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.911648Z',
#   'url': 'https://api.robinhood.com/options/instruments/2258d526-e4d8-4721-a7a4-ea5aa3d9b4cc/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.911550Z',
#   'expiration_date': '2020-11-27',
#   'id': '2fd45377-ac03-439a-89f9-342a3496db20',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '17.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.911556Z',
#   'url': 'https://api.robinhood.com/options/instruments/2fd45377-ac03-439a-89f9-342a3496db20/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.911504Z',
#   'expiration_date': '2020-11-27',
#   'id': '760feebc-f561-4046-b251-ddb70452a09b',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '20.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.911511Z',
#   'url': 'https://api.robinhood.com/options/instruments/760feebc-f561-4046-b251-ddb70452a09b/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.911320Z',
#   'expiration_date': '2020-11-27',
#   'id': '9993a49c-a286-4290-a17d-424aa6c09515',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '23.5000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.911326Z',
#   'url': 'https://api.robinhood.com/options/instruments/9993a49c-a286-4290-a17d-424aa6c09515/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.911226Z',
#   'expiration_date': '2020-11-27',
#   'id': '816b0b57-2e18-43d2-b313-9fe9af13aed2',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '20.5000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.911233Z',
#   'url': 'https://api.robinhood.com/options/instruments/816b0b57-2e18-43d2-b313-9fe9af13aed2/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.911179Z',
#   'expiration_date': '2020-11-27',
#   'id': '97cf7196-4bab-47e9-a8a5-0f93788c8004',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '24.5000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.911185Z',
#   'url': 'https://api.robinhood.com/options/instruments/97cf7196-4bab-47e9-a8a5-0f93788c8004/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.911083Z',
#   'expiration_date': '2020-11-27',
#   'id': '96434dcd-3723-4f4c-aee6-03227f718c5a',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '26.5000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.911090Z',
#   'url': 'https://api.robinhood.com/options/instruments/96434dcd-3723-4f4c-aee6-03227f718c5a/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.910974Z',
#   'expiration_date': '2020-11-27',
#   'id': '16581f24-1bfe-46bb-8827-d84308a1587e',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '26.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.910981Z',
#   'url': 'https://api.robinhood.com/options/instruments/16581f24-1bfe-46bb-8827-d84308a1587e/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.910928Z',
#   'expiration_date': '2020-11-27',
#   'id': 'dd34603a-0e2f-498e-9a04-78bd4ce03517',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '18.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.910935Z',
#   'url': 'https://api.robinhood.com/options/instruments/dd34603a-0e2f-498e-9a04-78bd4ce03517/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.910881Z',
#   'expiration_date': '2020-11-27',
#   'id': 'a470c20e-a1bb-4f9a-ae07-f5bf0ea9912d',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '24.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.910888Z',
#   'url': 'https://api.robinhood.com/options/instruments/a470c20e-a1bb-4f9a-ae07-f5bf0ea9912d/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.910741Z',
#   'expiration_date': '2020-11-27',
#   'id': '62db93eb-6863-41e4-b903-7af51fa1beb8',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '15.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.910747Z',
#   'url': 'https://api.robinhood.com/options/instruments/62db93eb-6863-41e4-b903-7af51fa1beb8/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.910648Z',
#   'expiration_date': '2020-11-27',
#   'id': '20827bd6-c773-4313-a4bd-4fd0788379f2',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '28.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.910654Z',
#   'url': 'https://api.robinhood.com/options/instruments/20827bd6-c773-4313-a4bd-4fd0788379f2/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.910529Z',
#   'expiration_date': '2020-11-27',
#   'id': '1f755c3a-0c77-4b15-acc4-2567f741dc5f',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '27.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.910535Z',
#   'url': 'https://api.robinhood.com/options/instruments/1f755c3a-0c77-4b15-acc4-2567f741dc5f/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.910484Z',
#   'expiration_date': '2020-11-27',
#   'id': 'ab3dab39-1f4b-461a-8500-4b0bee8e5747',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '27.5000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.910490Z',
#   'url': 'https://api.robinhood.com/options/instruments/ab3dab39-1f4b-461a-8500-4b0bee8e5747/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.910349Z',
#   'expiration_date': '2020-11-27',
#   'id': 'b0b5080c-4108-4063-b197-05ec324ffacb',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '22.5000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.910355Z',
#   'url': 'https://api.robinhood.com/options/instruments/b0b5080c-4108-4063-b197-05ec324ffacb/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.910304Z',
#   'expiration_date': '2020-11-27',
#   'id': '54e8da46-b530-4167-bdb6-3efb7de48e59',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '23.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.910310Z',
#   'url': 'https://api.robinhood.com/options/instruments/54e8da46-b530-4167-bdb6-3efb7de48e59/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.910169Z',
#   'expiration_date': '2020-11-27',
#   'id': '0f98e953-d9a8-4974-a822-634594eed47e',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '18.5000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.910176Z',
#   'url': 'https://api.robinhood.com/options/instruments/0f98e953-d9a8-4974-a822-634594eed47e/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.910123Z',
#   'expiration_date': '2020-11-27',
#   'id': '9bf6ae1a-218f-4ff1-966e-63e777458a5c',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '19.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.910130Z',
#   'url': 'https://api.robinhood.com/options/instruments/9bf6ae1a-218f-4ff1-966e-63e777458a5c/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.910078Z',
#   'expiration_date': '2020-11-27',
#   'id': '54993bce-b5bf-449e-a46a-4ebe562858ba',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '21.5000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.910084Z',
#   'url': 'https://api.robinhood.com/options/instruments/54993bce-b5bf-449e-a46a-4ebe562858ba/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.909988Z',
#   'expiration_date': '2020-11-27',
#   'id': '95b755e1-2e80-4821-bfac-8f5b07473e29',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '22.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.909994Z',
#   'url': 'https://api.robinhood.com/options/instruments/95b755e1-2e80-4821-bfac-8f5b07473e29/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.909942Z',
#   'expiration_date': '2020-11-27',
#   'id': 'eda88572-26fe-4a34-84b9-e16b7da1746d',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '21.0000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.909949Z',
#   'url': 'https://api.robinhood.com/options/instruments/eda88572-26fe-4a34-84b9-e16b7da1746d/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'},
#  {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#   'chain_symbol': 'NIO',
#   'created_at': '2020-10-08T03:48:58.909801Z',
#   'expiration_date': '2020-11-27',
#   'id': 'a8e1c0d4-0a3c-4c2b-9a9c-d7feb698b9a7',
#   'issue_date': '2018-09-18',
#   'min_ticks': {'above_tick': '0.05',
#    'below_tick': '0.01',
#    'cutoff_price': '3.00'},
#   'rhs_tradability': 'untradable',
#   'state': 'active',
#   'strike_price': '19.5000',
#   'tradability': 'tradable',
#   'type': 'call',
#   'updated_at': '2020-10-08T03:48:58.909808Z',
#   'url': 'https://api.robinhood.com/options/instruments/a8e1c0d4-0a3c-4c2b-9a9c-d7feb698b9a7/',
#   'sellout_datetime': '2020-11-27T17:00:00+00:00'}]

# %%
# r.stocks.get_stock_historicals(symbol, interval='week', span='3month')

# %%
d = r.options.find_tradable_options(symbol, '2020-11-27', optionType="call")

# %%
d[7]
# Out:
# {'chain_id': '2c081432-2180-4c5f-ae36-3587554758fc',
#  'chain_symbol': 'NIO',
#  'created_at': '2020-11-10T02:06:00.068290Z',
#  'expiration_date': '2020-11-27',
#  'id': '017fc802-6acf-492a-833e-b2d09dc8c797',
#  'issue_date': '2018-09-18',
#  'min_ticks': {'above_tick': '0.05',
#   'below_tick': '0.01',
#   'cutoff_price': '3.00'},
#  'rhs_tradability': 'untradable',
#  'state': 'active',
#  'strike_price': '65.0000',
#  'tradability': 'tradable',
#  'type': 'call',
#  'updated_at': '2020-11-10T02:06:00.068297Z',
#  'url': 'https://api.robinhood.com/options/instruments/017fc802-6acf-492a-833e-b2d09dc8c797/',
#  'sellout_datetime': '2020-11-27T17:00:00+00:00'}

# %%
r.options.get_option_market_data(symbol, expirations[0], 
                                 d[7]["strike_price"], "call")
# Out:
# [[{'adjusted_mark_price': '0.580000',
#    'ask_price': '0.600000',
#    'ask_size': 21,
#    'bid_price': '0.550000',
#    'bid_size': 13,
#    'break_even_price': '65.580000',
#    'high_price': '1.090000',
#    'instrument': 'https://api.robinhood.com/options/instruments/fa12ea32-c2c7-42e5-be84-27ad34f842aa/',
#    'last_trade_price': '0.590000',
#    'last_trade_size': 1,
#    'low_price': '0.370000',
#    'mark_price': '0.575000',
#    'open_interest': 16944,
#    'previous_close_date': '2020-11-13',
#    'previous_close_price': '1.040000',
#    'volume': 13034,
#    'chance_of_profit_long': '0.064739',
#    'chance_of_profit_short': '0.935261',
#    'delta': '0.111298',
#    'gamma': '0.015837',
#    'implied_volatility': '2.509395',
#    'rho': '0.000492',
#    'theta': '-0.283829',
#    'vega': '0.009048',
#    'high_fill_rate_buy_price': '0.600000',
#    'high_fill_rate_sell_price': '0.550000',
#    'low_fill_rate_buy_price': '0.570000',
#    'low_fill_rate_sell_price': '0.580000'}]]
